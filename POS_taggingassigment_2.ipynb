# %% [markdown]
# # **Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy). Analyze the grammatical structure of sentences using syntactic/dependency parsing.**

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = """
From Wikipedia, the free encyclopedia
"Shastri" redirects here. For other uses, see Shastri (disambiguation).
Lal Bahadur Shastri

Prime Minister of India
In office
9 June 1964 – 11 January 1966
President	Sarvepalli Radhakrishnan
Vice President	Zakir Husain
Preceded by	Jawaharlal Nehru[a]
Succeeded by	Indira Gandhi[b]
Union Minister of External Affairs
In office
9 June 1964 – 18 July 1964
Prime Minister	Himself
Preceded by	Gulzarilal Nanda
Succeeded by	Sardar Swaran Singh
Union Minister of Home Affairs
In office
4 April 1961 – 29 August 1963
Prime Minister	Jawaharlal Nehru
Preceded by	Govind Ballabh Pant
Succeeded by	Gulzarilal Nanda
Union Minister of Railways
In office
13 May 1952 – 7 December 1956
Prime Minister	Jawaharlal Nehru
Preceded by	N. Gopalaswami Ayyangar
Succeeded by	Jagjivan Ram
Personal details
Born	Lal Bahadur Srivastava
2 October 1904
Mughalsarai, United Provinces of Agra and Oudh, British India
Died	11 January 1966 (aged 61)
Tashkent, Uzbek SSR, Soviet Union
Cause of death	Heart attack
Party	Indian National Congress
Spouse	Lalita Shastri ​(m. 1928)​
Children	6; including Anil Shastri, Hari Krishna Shastri and Sunil Shastri
Alma mater	Mahatma Gandhi Kashi Vidyapith, Varanasi
Profession	Politician
Nickname	Nanhe

This article is part of
a series about
Lal Bahadur Shastri
Prime Minister of India
(1964–1966)
Early life and educationGandhi's discipleJai Jawan Jai KisanDeath and state funeralEponyms
Premiership

Union Council of Ministers ShastriLok Sabha ThirdDomestic policiesEconomic policiesForeign policies
Constitutional amendments

18th19th20th
Events

White RevolutionSirima–Shastri PactIndo-Pakistani War of 1965 Tashkent Declaration
Lalita ShastriJai Jawaan Jai KisaanThe Tashkent Files
Gallery: Picture, Sound, Video
vte
Lal Bahadur Shastri[c] (2 October 1904 – 11 January 1966) was an Indian politician and statesman who served as the prime minister of India from 1964 to 1966. He previously served as home minister from 1961 to 1963.

Shastri was born to Sharad Prasad Srivastava and Ramdulari Devi in Mughalsarai on 2 October 1904. He studied in East Central Railway Inter college and the Harish Chandra High School, which he left to join the non-cooperation movement. He worked for the betterment of the Harijans at Muzaffarpur and dropped his caste-derived surname of "Srivastava". Influenced by Mahatma Gandhi, he joined the Indian Independence movement in the 1920s. He served as the president of Servants of the People Society, founded by Lala Lajpat Rai and held prominent positions in the Indian National Congress (INC). Following Indian independence in 1947, Shastri led several union ministries under prime minister Jawaharlal Nehru.

As prime minister, Shastri promoted the White revolution (India), a national campaign to increase the production and supply of milk, by supporting the Amul milk co-operative and creating the National Dairy Development Board. Underlining the need to boost India's food production, Shastri also promoted the Green Revolution in India in 1965. This led to an increase in food grain production, especially in the states of Punjab, Haryana and Uttar Pradesh. He led the country during the Indo-Pakistani war of 1965. His slogan "Jai Jawan, Jai Kisan" ("Hail to the soldier; Hail to the farmer") became very popular during the war. The war formally ended with the Tashkent Declaration on 10 January 1966; Shastri died the next day.

Early years (1904–1920)
Shastri was born on 2 October 1904 at the home of his maternal grandparents.[1][2] Shastri's paternal ancestors were in the service of the zamindar of Ramnagar in Banaras, and Shastri lived there for the first year of his life. Shastri's father, Sharad Prasad Srivastava, was a school teacher who later became a clerk in the revenue office at Prayagraj, while his mother, Ramdulari Devi, was the daughter of Munshi Hazari Lal, the headmaster and English teacher at a railway school in Mughalsarai. Shastri was the second child and eldest son of his parents; he had an elder sister, Kailashi Devi (b. 1900).[3][4]

In April 1905, when Shastri was hardly 18 months old, his father, who had recently been promoted to the post of deputy tehsildar, died in an epidemic of bubonic plague. Ramdulari Devi, then only 23 years old and pregnant with her third child, took her two children and moved from Ramnagar to her father's house in Mughalsarai and settled there for good. She gave birth to a daughter, Sundari Devi, in July 1906.[5][6] Thus, Shastri and his sisters grew up in the household of his maternal grandfather, Hazari Lalji.[7] However, Hazari Lalji himself died from a stroke in mid-1908. Thereafter, the family was looked after by his brother (Shastri's great-uncle) Darbari Lal, who was the head clerk in the opium regulation department at Ghazipur, and later by his son (Ramdulari Devi's cousin) Bindeshwari Prasad, a school teacher in Mughalsarai.[8]

This situation was standard for the time, where the Indian joint family system was a thriving reality; the sense of family relationship and responsibility it fostered was the primary social security of the time. Nor should it be surmised from these circumstances that Shastri grew up in an under-privileged manner, or that his education and comforts were compromised. On the contrary, since he was a rank student, he received a better education than some of his cousins.[9] Bindeshwari Prasad, on the limited salary of a school teacher, with many dependents, nevertheless managed to give a good education to all the children in his care.

In 1917, Bindeshwari Prasad was transferred to Varanasi, and the entire family moved there, including Ramdulari Devi and her three children. In Varanasi, Shastri joining the seventh standard at Harish Chandra High School.

Early activities (1921–1945)
While his family had no links to the independence movement then taking shape, among his teachers at Harish Chandra High School was an intensely patriotic and highly respected teacher named Nishkameshwar Prasad Mishra, who gave Shastri much-needed financial support by allowing him to tutor his children. Inspired by Mishra's patriotism, Shastri took a deep interest in the freedom struggle, and began to study its history and the works of several of its noted personalities, including those of Swami Vivekananda, Mahatma Gandhi and Annie Besant.[citation needed] In January 1921, when Shastri was in the 10th standard and three months from sitting the final examinations, he attended a public meeting in Benares hosted by Gandhi and Pandit Madan Mohan Malaviya. Inspired by the Mahatma's call for students to withdraw from government schools and join the non-cooperation movement, Shastri withdrew from Harish Chandra High School the next day and joined the local branch of the Congress Party as a volunteer, actively participating in picketing and anti-government demonstrations.[10] He was soon arrested and jailed, but was then let off as he was still a minor.[11][12]

Shastri's immediate supervisor was a former Benares Hindu University lecturer named J.B. Kripalani, who would become one of the most prominent leaders of the Indian independence movement and one among Gandhi's closest followers.[13] Recognising the need for the younger volunteers to continue their educations, Kripalani and a friend, V.N. Sharma, had founded an informal school centered around "nationalist education" to educate the young activists in their nation's heritage and with the support of a wealthy philanthropist and ardent Congress nationalist, Shiv Prasad Gupta, the Kashi Vidyapith was inaugurated by Gandhi in Benares as a national institution of higher education on 10 February 1921. Among the first students of the new institution, Shastri graduated with a first-class degree in philosophy and ethics from the Vidyapith in 1925. He was given the title Shastri ("scholar").[14] The title was a bachelor's degree awarded by the institution but it stuck as part of his name.[15][16]

Shastri enrolled himself as a life member of the Servants of the People Society (Lok Sevak Mandal), founded by Lala Lajpat Rai, and began to work for the betterment of the Harijans under Gandhi's direction at Muzaffarpur.[17] Later he became the President of the Society.[18][19]

Independence Activism of Lal Bahadur Shastri
In 1928 Shastri became an active and mature member of the Indian National Congress at the call of Mahatma Gandhi. He was imprisoned for two and a half years.[20] Later, he worked as the Organizing Secretary of the Parliamentary Board of U.P. in 1937.[21] In 1940, he was sent to prison for one year, for offering individual Satyagraha support to the independence movement.[22]

On 8 August 1942, Mahatma Gandhi issued the Quit India speech at Gowalia Tank in Bombay, demanding that the British leave India. Shastri, who had just then come out after a year in prison, travelled to Allahabad. For a week, he sent instructions to the independence activists from Jawaharlal Nehru's home, Anand Bhavan.[23] He served as an elected representative for United Provinces in 1937 and 1946.[24]

Political career (1947–1964)
State minister
Following India's independence, Shastri was appointed Parliamentary Secretary in his home state, Uttar Pradesh.[25] He became the Minister of Police and Transport under Govind Ballabh Pant's Chief Ministership on 15 August 1947 following Rafi Ahmed Kidwai's departure to become a minister at the centre. As the Transport Minister, he was the first to appoint women conductors. As the minister in charge of the Police Department, he ordered that police use water jets, whose instructions was given by him, instead of lathis to disperse unruly crowds.[26] His tenure as police minister (As Home Minister was called prior to 1950) saw successful curbing of communal riots in 1947, mass migration and resettlement of refugees.[27]

Cabinet minister
See also: Cabinet of India

Jawaharlal Nehru with Lal Bahadur Shastri and K. Kamaraj
In 1951, Shastri was made the General Secretary of the All-India Congress Committee with Jawaharlal Nehru as the prime minister. He was directly responsible for the selection of candidates and the direction of publicity and electioneering activities. He played an important role in the landslide successes of the Congress Party in the Indian General Elections of 1952, 1957 and 1962. In 1952, he successfully contested UP Vidhansabha from Soraon North cum Phulpur West seat and won by getting over 69% of vote. He was believed to be retained as home minister of UP, but in a surprise move was called to Centre as minister by Nehru. Shastri was made Minister of Railways and Transport in First Cabinet of Republic of India on 13 May 1952.[28]

In September 1956 he wanted to take political and moral responsibility for the 1956 Mahbubnagar train accident and offered his resignation as the Minister of Railways to prime minister Jawaharlal Nehru, but he refused. After the 1956 Ariyalur train accident, a similar accident about 2.5 months later, Shastri again offered his resignation and was accepted this time.[29][30] He resigned as Railway minister on 7 December 1956.[31]

He served as the Minister of Commerce and Industry in 1959 and Minister of Home Affairs in 1961.[32] Shastri laid the foundation of Mangalore Port in 1964 as a minister without a portfolio.[33]

Prime Minister (1964–1966)
Main article: Premiership of Lal Bahadur Shastri
See also: Lal Bahadur Shastri ministry
Jawaharlal Nehru died in office on 27 May 1964. Then Congress Party president K. Kamaraj was instrumental in making Shastri prime minister on 9 June. Shastri, though mild-mannered and soft-spoken, was a Nehruvian socialist and thus held appeal to those wishing to prevent the ascent of conservative right-winger Morarji Desai.

In his first broadcast as prime minister, on 11 June 1964, Shastri stated:[34]

There comes a time in the life of every nation when it stands at the cross-roads of history and must choose which way to go. But for us, there need be no difficulty or hesitation, no looking to right or left. Our way is straight and clear—the building up of a socialist democracy at home with freedom and prosperity for all, and the maintenance of world peace and friendship with all nations.

Domestic policies
Shastri retained many members of Nehru's Council of Ministers. T. T. Krishnamachari was retained as the Finance Minister of India, as was Defence Minister Yashwantrao Chavan. Further, He appointed Swaran Singh to succeed him as External Affairs Minister. He also appointed Indira Gandhi, daughter of Jawaharlal Nehru and former Congress President, as the Minister of Information and Broadcasting. Gulzarilal Nanda continued as the Minister of Home Affairs.[35]

Main article: Anti-Hindi agitations of Tamil Nadu
Lal Bahadur Shastri's tenure witnessed the Madras anti-Hindi agitation of 1965. The government of India had for a long time made an effort to establish Hindi as the sole national language of India. This was resisted by the non-Hindi speaking states particularly Madras State.[36] To calm the situation, Shastri gave assurances that English would continue to be used as the official language as long the non-Hindi speaking states wanted. The riots subsided after Shastri's assurance, as did the student agitation.[37]

Economic policies

Inauguration of the Main Building of MNREC Allahabad by Lal Bahadur Shashtri on 18 April 1965
Shastri continued Nehru's socialist economic policies with central planning.[38] He promoted the White revolution (India) – a national campaign to increase the production and supply of milk – by supporting the Amul milk co-operative of Anand, Gujarat and creating the National Dairy Development Board.[39] He visited Anand on 31 October 1964 for inauguration of the Cattle Feed Factory of Amul at Kanjari. As he was keenly interested in knowing the success of this co-operative, he stayed overnight with farmers in a village, and even had dinner with a farmer's family. He discussed his wish with Verghese Kurien, then the General Manager of Kaira District Co-operative Milk Producers' Union Ltd (Amul) to replicate this model to other parts of the country for improving the socio-economic conditions of farmers. As a result of this visit, the National Dairy Development Board (NDDB) was established at Anand in 1965.[40]

While speaking on the chronic food shortages across the country, Shastri urged people to voluntarily give up one meal so that the food saved could be distributed to the affected populace. However, he ensured that he first implemented the system in his own family before appealing to the country. He went on air to appeal to his countrymen to skip a meal a week. The response to his appeal was overwhelming. Even restaurants and eateries downed the shutters on Monday evenings. Many parts of the country observed the "Shastri Vrat". He motivated the country to maximize the cultivation of food grains by ploughing the lawn himself, at his official residence in New Delhi. During the 22-day war with Pakistan in 1965, On 19 October 1965, Shastri gave the seminal 'Jai Jawan Jai Kishan' ("Hail the soldier, Hail the farmer") slogan at Urwa in Allahabad that became a national slogan. Underlining the need to boost India's food production, Shastri also promoted the Green Revolution in India in 1965.[41][42][43] This led to an increase in food grain production, especially in Punjab, Haryana, and Uttar Pradesh. Major milestones in this undertaking were the development of high-yielding varieties of wheat,[44] and rust resistant strains of wheat.[45][46]


Lal Bahadur Shastri in 1964
Though he was a socialist, Shastri stated that India cannot have a regimented type of economy. His government passed the National Agricultural Products Board Act and was responsible for setting up the Food Corporation of India under the Food Corporation's Act 1964.[47]

Jai Jawan Jai Kisan
Main article: Jai Jawan Jai Kisan
For the outstanding slogan given by him during the Indo-Pak war of 1965, the Ministry of Information and Broadcasting (India) commemorated Shastri 47 years after his death on his 48th martyr's day:[48]
"""

# %%
doc=nlp(text)

# %% [markdown]
# #POS tagging

# %%
for token in doc:
    print(f"{token.text:15}  POS: {token.pos_:10}  TAG: {token.tag_:10}  DEP: {token.dep_}  Description: {spacy.explain(token.tag_)}")
# Out:
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# From             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Wikipedia        POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# free             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# encyclopedia     POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# Shastri          POS: ADJ         TAG: JJR         DEP: amod  Description: adjective, comparative
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# redirects        POS: NOUN        TAG: NNS         DEP: ROOT  Description: noun, plural
# here             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# For              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# other            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# uses             POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# see              POS: VERB        TAG: VB          DEP: ROOT  Description: verb, base form
# Shastri          POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# disambiguation   POS: NOUN        TAG: NN          DEP: appos  Description: noun, singular or mass
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lal              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Bahadur          POS: PROPN       TAG: NNP         DEP: ROOT  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Prime            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# In               POS: ADP         TAG: IN          DEP: ROOT  Description: conjunction, subordinating or preposition
# office           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 9                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# June             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 1964             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# –                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# 11               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# 1966             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# President        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Sarvepalli       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Radhakrishnan    POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Vice             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# President        POS: PROPN       TAG: NNP         DEP: dep  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Zakir            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Husain           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Preceded         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Jawaharlal       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Nehru[a          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Succeeded        POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Indira           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Gandhi[b         POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Union            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# External         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Affairs          POS: PROPN       TAG: NNPS        DEP: pobj  Description: noun, proper plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# In               POS: ADP         TAG: IN          DEP: ROOT  Description: conjunction, subordinating or preposition
# office           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 9                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# June             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 1964             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# –                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# 18               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# July             POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# 1964             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Prime            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Himself          POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Preceded         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Gulzarilal       POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# Nanda            POS: PROPN       TAG: NNP         DEP: dep  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Succeeded        POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Sardar           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Swaran           POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# Singh            POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Union            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Home             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Affairs          POS: PROPN       TAG: NNPS        DEP: pobj  Description: noun, proper plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# In               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# office           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 4                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# April            POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1961             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# –                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# 29               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# August           POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1963             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Prime            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Jawaharlal       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Nehru            POS: PROPN       TAG: NNP         DEP: punct  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Preceded         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Govind           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Ballabh          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Pant             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Succeeded        POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Gulzarilal       POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# Nanda            POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Union            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Railways         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# In               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# office           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 13               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# May              POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1952             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# –                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# 7                POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# December         POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1956             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Prime            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Jawaharlal       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Nehru            POS: PROPN       TAG: NNP         DEP: punct  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Preceded         POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# N.               POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Gopalaswami      POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Ayyangar         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Succeeded        POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Jagjivan         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Ram              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Personal         POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# details          POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Born             POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lal              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Bahadur          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Srivastava       POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 2                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# October          POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# 1904             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Mughalsarai      POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# United           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Provinces        POS: PROPN       TAG: NNPS        DEP: appos  Description: noun, proper plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Agra             POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Oudh             POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# British          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# India            POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Died             POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 11               POS: NUM         TAG: CD          DEP: dobj  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1966             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# aged             POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# 61               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Tashkent         POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Uzbek            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# SSR              POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Soviet           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Union            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Cause            POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# death            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Heart            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# attack           POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Party            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Indian           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# National         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Congress         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Spouse           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lalita           POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# ​(m              POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# 1928)​           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Children         POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 6                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# ;                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# including        POS: VERB        TAG: VBG         DEP: prep  Description: verb, gerund or present participle
# Anil             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Hari             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Krishna          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Sunil            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Alma             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# mater            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Mahatma          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Gandhi           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Kashi            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Vidyapith        POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Varanasi         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Profession       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Politician       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Nickname         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 	                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Nanhe            POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
#
#
#               POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# This             POS: DET         TAG: DT          DEP: det  Description: determiner
# article          POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# is               POS: AUX         TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# part             POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# series           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# about            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lal              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Bahadur          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Prime            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Minister         POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# 1964–1966        POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Early            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# life             POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# educationGandhi  POS: VERB        TAG: VBZ         DEP: ROOT  Description: verb, 3rd person singular present
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# discipleJai      POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# Jawan            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jai              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# KisanDeath       POS: PROPN       TAG: NNP         DEP: attr  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# state            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# funeralEponyms   POS: NOUN        TAG: NNS         DEP: nmod  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Premiership      POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Union            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Council          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Ministers        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# ShastriLok       POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# Sabha            POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# ThirdDomestic    POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
# policiesEconomic  POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# policiesForeign  POS: VERB        TAG: VBP         DEP: amod  Description: verb, non-3rd person singular present
# policies         POS: NOUN        TAG: NNS         DEP: ROOT  Description: noun, plural
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Constitutional   POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# amendments       POS: NOUN        TAG: NNS         DEP: appos  Description: noun, plural
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# 18th19th20th     POS: ADP         TAG: IN          DEP: punct  Description: conjunction, subordinating or preposition
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Events           POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# White            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# RevolutionSirima  POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# –                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Shastri          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# PactIndo         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# Pakistani        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# War              POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1965             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# Tashkent         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Declaration      POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lalita           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# ShastriJai       POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jawaan           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jai              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# KisaanThe        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Tashkent         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Files            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Gallery          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Picture          POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Sound            POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Video            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# vte              POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lal              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Bahadur          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Shastri[c        POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# ]                POS: X           TAG: XX          DEP: punct  Description: unknown
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# 2                POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# October          POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# 1904             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# –                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# 11               POS: NUM         TAG: CD          DEP: appos  Description: cardinal number
# January          POS: PROPN       TAG: NNP         DEP: npadvmod  Description: noun, proper singular
# 1966             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# was              POS: AUX         TAG: VBD         DEP: ROOT  Description: verb, past tense
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# Indian           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# politician       POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# statesman        POS: NOUN        TAG: NN          DEP: conj  Description: noun, singular or mass
# who              POS: PRON        TAG: WP          DEP: nsubj  Description: wh-pronoun, personal
# served           POS: VERB        TAG: VBD         DEP: relcl  Description: verb, past tense
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# prime            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# minister         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1964             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1966             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# He               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# previously       POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# served           POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# home             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# minister         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# from             POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1961             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1963             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Shastri          POS: PROPN       TAG: NNP         DEP: nsubjpass  Description: noun, proper singular
# was              POS: AUX         TAG: VBD         DEP: auxpass  Description: verb, past tense
# born             POS: VERB        TAG: VBN         DEP: ROOT  Description: verb, past participle
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Sharad           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Prasad           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Srivastava       POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Ramdulari        POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Devi             POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Mughalsarai      POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 2                POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# October          POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# 1904             POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# He               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# studied          POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# East             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Central          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Railway          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Inter            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# college          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Harish           POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Chandra          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# High             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# School           POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# which            POS: PRON        TAG: WDT         DEP: dobj  Description: wh-determiner
# he               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# left             POS: VERB        TAG: VBD         DEP: relcl  Description: verb, past tense
# to               POS: PART        TAG: TO          DEP: aux  Description: infinitival "to"
# join             POS: VERB        TAG: VB          DEP: xcomp  Description: verb, base form
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# non              POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# -                POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# cooperation      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# movement         POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# He               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# worked           POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# betterment       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Harijans         POS: PROPN       TAG: NNPS        DEP: pobj  Description: noun, proper plural
# at               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Muzaffarpur      POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# dropped          POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# his              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# caste            POS: NOUN        TAG: NN          DEP: npadvmod  Description: noun, singular or mass
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# derived          POS: VERB        TAG: VBN         DEP: amod  Description: verb, past participle
# surname          POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# "                POS: PUNCT       TAG: ``          DEP: punct  Description: opening quotation mark
# Srivastava       POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# "                POS: PUNCT       TAG: ''          DEP: punct  Description: closing quotation mark
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Influenced       POS: VERB        TAG: VBN         DEP: advcl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# Mahatma          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Gandhi           POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# he               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# joined           POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Indian           POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# Independence     POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# movement         POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# 1920s            POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# He               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# served           POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# as               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# ...
# promoted         POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Green            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Revolution       POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1965.[41][42][43  POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# This             POS: PRON        TAG: DT          DEP: nsubj  Description: determiner
# led              POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# to               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# an               POS: DET         TAG: DT          DEP: det  Description: determiner
# increase         POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# food             POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# grain            POS: NOUN        TAG: NN          DEP: compound  Description: noun, singular or mass
# production       POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# especially       POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Punjab           POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Haryana          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Uttar            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Pradesh          POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# Major            POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# milestones       POS: NOUN        TAG: NNS         DEP: nsubj  Description: noun, plural
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# this             POS: DET         TAG: DT          DEP: det  Description: determiner
# undertaking      POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# were             POS: AUX         TAG: VBD         DEP: ROOT  Description: verb, past tense
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# development      POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# high             POS: ADV         TAG: RB          DEP: advmod  Description: adverb
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# yielding         POS: VERB        TAG: VBG         DEP: amod  Description: verb, gerund or present participle
# varieties        POS: NOUN        TAG: NNS         DEP: pobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# wheat,[44        POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# rust             POS: VERB        TAG: VB          DEP: conj  Description: verb, base form
# resistant        POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# strains          POS: NOUN        TAG: NNS         DEP: dobj  Description: noun, plural
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# wheat.[45][46    POS: X           TAG: FW          DEP: pobj  Description: foreign word
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#
#               POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Lal              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Bahadur          POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Shastri          POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# in               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1964             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Though           POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# he               POS: PRON        TAG: PRP         DEP: nsubj  Description: pronoun, personal
# was              POS: AUX         TAG: VBD         DEP: advcl  Description: verb, past tense
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# socialist        POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# Shastri          POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# stated           POS: VERB        TAG: VBD         DEP: conj  Description: verb, past tense
# that             POS: SCONJ       TAG: IN          DEP: mark  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# can              POS: AUX         TAG: MD          DEP: aux  Description: verb, modal auxiliary
# not              POS: PART        TAG: RB          DEP: neg  Description: adverb
# have             POS: VERB        TAG: VB          DEP: ccomp  Description: verb, base form
# a                POS: DET         TAG: DT          DEP: det  Description: determiner
# regimented       POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# type             POS: NOUN        TAG: NN          DEP: dobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# economy          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# .                POS: PUNCT       TAG: .           DEP: punct  Description: punctuation mark, sentence closer
# His              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# government       POS: NOUN        TAG: NN          DEP: nsubj  Description: noun, singular or mass
# passed           POS: VERB        TAG: VBD         DEP: ccomp  Description: verb, past tense
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# National         POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Agricultural     POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Products         POS: PROPN       TAG: NNPS        DEP: compound  Description: noun, proper plural
# Board            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Act              POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# was              POS: AUX         TAG: VBD         DEP: conj  Description: verb, past tense
# responsible      POS: ADJ         TAG: JJ          DEP: acomp  Description: adjective (English), other noun-modifier (Chinese)
# for              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# setting          POS: VERB        TAG: VBG         DEP: pcomp  Description: verb, gerund or present participle
# up               POS: ADP         TAG: RP          DEP: prt  Description: adverb, particle
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Food             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Corporation      POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# India            POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# under            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Food             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Corporation      POS: PROPN       TAG: NNP         DEP: poss  Description: noun, proper singular
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# Act              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# 1964.[47         POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#
#                POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Jai              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jawan            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jai              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Kisan            POS: PROPN       TAG: NNP         DEP: nmod  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# Main             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# article          POS: NOUN        TAG: NN          DEP: attr  Description: noun, singular or mass
# :                POS: PUNCT       TAG: :           DEP: punct  Description: punctuation mark, colon or ellipsis
# Jai              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jawan            POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Jai              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# Kisan            POS: PROPN       TAG: NNP         DEP: dobj  Description: noun, proper singular
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace
# For              POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# outstanding      POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# slogan           POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# given            POS: VERB        TAG: VBN         DEP: acl  Description: verb, past participle
# by               POS: ADP         TAG: IN          DEP: agent  Description: conjunction, subordinating or preposition
# him              POS: PRON        TAG: PRP         DEP: pobj  Description: pronoun, personal
# during           POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Indo             POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# -                POS: PUNCT       TAG: HYPH        DEP: punct  Description: punctuation mark, hyphen
# Pak              POS: PROPN       TAG: NNP         DEP: compound  Description: noun, proper singular
# war              POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# 1965             POS: NUM         TAG: CD          DEP: pobj  Description: cardinal number
# ,                POS: PUNCT       TAG: ,           DEP: punct  Description: punctuation mark, comma
# the              POS: DET         TAG: DT          DEP: det  Description: determiner
# Ministry         POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# of               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# Information      POS: PROPN       TAG: NNP         DEP: pobj  Description: noun, proper singular
# and              POS: CCONJ       TAG: CC          DEP: cc  Description: conjunction, coordinating
# Broadcasting     POS: PROPN       TAG: NNP         DEP: conj  Description: noun, proper singular
# (                POS: PUNCT       TAG: -LRB-       DEP: punct  Description: left round bracket
# India            POS: PROPN       TAG: NNP         DEP: appos  Description: noun, proper singular
# )                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
# commemorated     POS: VERB        TAG: VBD         DEP: ROOT  Description: verb, past tense
# Shastri          POS: PROPN       TAG: NNP         DEP: nsubj  Description: noun, proper singular
# 47               POS: NUM         TAG: CD          DEP: nummod  Description: cardinal number
# years            POS: NOUN        TAG: NNS         DEP: npadvmod  Description: noun, plural
# after            POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# his              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# death            POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# on               POS: ADP         TAG: IN          DEP: prep  Description: conjunction, subordinating or preposition
# his              POS: PRON        TAG: PRP$        DEP: poss  Description: pronoun, possessive
# 48th             POS: ADJ         TAG: JJ          DEP: amod  Description: adjective (English), other noun-modifier (Chinese)
# martyr           POS: NOUN        TAG: NN          DEP: poss  Description: noun, singular or mass
# 's               POS: PART        TAG: POS         DEP: case  Description: possessive ending
# day:[48          POS: NOUN        TAG: NN          DEP: pobj  Description: noun, singular or mass
# ]                POS: PUNCT       TAG: -RRB-       DEP: punct  Description: right round bracket
#
#                 POS: SPACE       TAG: _SP         DEP: dep  Description: whitespace

# %% [markdown]
# #Dependency Parsing

# %%
for token in doc:
    print(f"{token.text:12} <--{token.dep_:10}-- {token.head.text}")
# Out:
#             <--dep       -- From
# From         <--prep      -- redirects
# Wikipedia    <--pobj      -- From
# ,            <--punct     -- Wikipedia
# the          <--det       -- encyclopedia
# free         <--amod      -- encyclopedia
# encyclopedia <--compound  -- redirects
#
#             <--dep       -- encyclopedia
# "            <--punct     -- redirects
# Shastri      <--amod      -- redirects
# "            <--punct     -- redirects
# redirects    <--ROOT      -- redirects
# here         <--advmod    -- redirects
# .            <--punct     -- redirects
# For          <--prep      -- see
# other        <--amod      -- uses
# uses         <--pobj      -- For
# ,            <--punct     -- see
# see          <--ROOT      -- see
# Shastri      <--nsubj     -- see
# (            <--punct     -- disambiguation
# disambiguation <--appos     -- Shastri
# )            <--punct     -- see
# .            <--punct     -- see
#
#             <--dep       -- .
# Lal          <--compound  -- Bahadur
# Bahadur      <--ROOT      -- Bahadur
# Shastri      <--compound  -- Minister
#
#
#            <--dep       -- Shastri
# Prime        <--compound  -- Minister
# Minister     <--appos     -- Bahadur
# of           <--prep      -- Minister
# India        <--pobj      -- of
#
#             <--dep       -- India
# In           <--ROOT      -- In
# office       <--pobj      -- In
#
#             <--dep       -- office
# 9            <--nummod    -- June
# June         <--pobj      -- In
# 1964         <--nummod    -- June
# –            <--punct     -- June
# 11           <--nummod    -- June
# January      <--nmod      -- President
# 1966         <--nummod    -- January
#
#             <--dep       -- 1966
# President    <--compound  -- President
# 	            <--dep       -- President
# Sarvepalli   <--compound  -- Radhakrishnan
# Radhakrishnan <--compound  -- President
#
#             <--dep       -- Radhakrishnan
# Vice         <--compound  -- President
# President    <--dep       -- In
# 	            <--dep       -- President
# Zakir        <--compound  -- Husain
# Husain       <--compound  -- Preceded
#
#             <--dep       -- Husain
# Preceded     <--acl       -- President
# by           <--prep      -- Preceded
# 	            <--dep       -- by
# Jawaharlal   <--compound  -- Nehru[a
# Nehru[a      <--pobj      -- by
# ]            <--punct     -- Preceded
#
#             <--dep       -- ]
# Succeeded    <--acl       -- President
# by           <--agent     -- Succeeded
# 	            <--dep       -- by
# Indira       <--compound  -- Minister
# Gandhi[b     <--nmod      -- Minister
# ]            <--punct     -- Gandhi[b
#
#             <--dep       -- ]
# Union        <--compound  -- Minister
# Minister     <--pobj      -- by
# of           <--prep      -- Minister
# External     <--compound  -- Affairs
# Affairs      <--pobj      -- of
#
#             <--dep       -- Affairs
# In           <--ROOT      -- In
# office       <--pobj      -- In
#
#             <--dep       -- office
# 9            <--nummod    -- June
# June         <--pobj      -- In
# 1964         <--nummod    -- June
# –            <--punct     -- June
# 18           <--nummod    -- Minister
# July         <--nmod      -- Minister
# 1964         <--nummod    -- July
#
#             <--dep       -- 1964
# Prime        <--compound  -- Minister
# Minister     <--appos     -- June
# 	            <--dep       -- Minister
# Himself      <--appos     -- Minister
#
#             <--dep       -- Himself
# Preceded     <--acl       -- Minister
# by           <--agent     -- Preceded
# 	            <--dep       -- by
# Gulzarilal   <--pobj      -- by
# Nanda        <--dep       -- Died
#
#             <--dep       -- Nanda
# Succeeded    <--acl       -- Nanda
# by           <--agent     -- Succeeded
# 	            <--dep       -- by
# Sardar       <--compound  -- Minister
# Swaran       <--nmod      -- Singh
# Singh        <--nmod      -- Minister
#
#             <--dep       -- Singh
# Union        <--compound  -- Minister
# Minister     <--pobj      -- by
# of           <--prep      -- Minister
# Home         <--compound  -- Affairs
# Affairs      <--pobj      -- of
#
#             <--dep       -- Affairs
# In           <--prep      -- Nanda
# office       <--pobj      -- In
#
#             <--dep       -- office
# 4            <--nummod    -- April
# April        <--npadvmod  -- Nanda
# 1961         <--nummod    -- April
# –            <--punct     -- Nanda
# 29           <--nummod    -- August
# August       <--npadvmod  -- Nanda
# 1963         <--nummod    -- August
#
#             <--dep       -- 1963
# Prime        <--compound  -- Minister
# Minister     <--compound  -- Nehru
# 	            <--dep       -- Minister
# Jawaharlal   <--compound  -- Nehru
# Nehru        <--punct     -- August
#
#             <--dep       -- Nehru
# Preceded     <--acl       -- Nehru
# by           <--prep      -- Preceded
# 	            <--dep       -- by
# Govind       <--compound  -- Pant
# Ballabh      <--compound  -- Pant
# Pant         <--pobj      -- by
#
#             <--dep       -- Pant
# Succeeded    <--acl       -- Nehru
# by           <--agent     -- Succeeded
# 	            <--dep       -- by
# Gulzarilal   <--nmod      -- Minister
# Nanda        <--nmod      -- Minister
#
#             <--dep       -- Nanda
# Union        <--compound  -- Minister
# Minister     <--pobj      -- by
# of           <--prep      -- Minister
# Railways     <--pobj      -- of
#
#             <--dep       -- Railways
# In           <--prep      -- Nanda
# office       <--pobj      -- In
#
#             <--dep       -- office
# 13           <--nummod    -- Nanda
# May          <--npadvmod  -- Nanda
# 1952         <--nummod    -- May
# –            <--punct     -- Nanda
# 7            <--appos     -- Nanda
# December     <--npadvmod  -- Died
# 1956         <--nummod    -- December
#
#             <--dep       -- 1956
# Prime        <--compound  -- Minister
# Minister     <--compound  -- Nehru
# 	            <--dep       -- Minister
# Jawaharlal   <--compound  -- Nehru
# Nehru        <--punct     -- December
#
#             <--dep       -- Nehru
# Preceded     <--acl       -- Nehru
# by           <--prep      -- Preceded
# 	            <--dep       -- by
# N.           <--compound  -- Gopalaswami
# Gopalaswami  <--compound  -- Ayyangar
# Ayyangar     <--pobj      -- by
#
#             <--dep       -- Ayyangar
# Succeeded    <--acl       -- December
# by           <--agent     -- Succeeded
# 	            <--dep       -- by
# Jagjivan     <--compound  -- details
# Ram          <--compound  -- details
#
#             <--dep       -- Ram
# Personal     <--amod      -- details
# details      <--pobj      -- by
#
#             <--dep       -- details
# Born         <--amod      -- Srivastava
# 	            <--dep       -- Born
# Lal          <--compound  -- Srivastava
# Bahadur      <--compound  -- Srivastava
# Srivastava   <--appos     -- details
#
#             <--dep       -- Srivastava
# 2            <--nummod    -- Mughalsarai
# October      <--nmod      -- Mughalsarai
# 1904         <--nummod    -- October
#
#             <--dep       -- 1904
# Mughalsarai  <--appos     -- Srivastava
# ,            <--punct     -- Mughalsarai
# United       <--compound  -- Provinces
# Provinces    <--appos     -- Mughalsarai
# of           <--prep      -- Provinces
# Agra         <--pobj      -- of
# and          <--cc        -- Agra
# Oudh         <--conj      -- Agra
# ,            <--punct     -- Died
# British      <--compound  -- India
# India        <--nsubj     -- Died
#
#             <--dep       -- India
# Died         <--ROOT      -- Died
# 	            <--dep       -- Died
# 11           <--dobj      -- Died
# January      <--npadvmod  -- Died
# 1966         <--nummod    -- January
# (            <--punct     -- aged
# aged         <--advcl     -- Died
# 61           <--nummod    -- aged
# )            <--punct     -- 61
#
#             <--dep       -- )
# Tashkent     <--npadvmod  -- aged
# ,            <--punct     -- Tashkent
# Uzbek        <--compound  -- SSR
# SSR          <--conj      -- Tashkent
# ,            <--punct     -- Tashkent
# Soviet       <--compound  -- Cause
# Union        <--compound  -- Cause
#
#             <--dep       -- Union
# Cause        <--appos     -- Tashkent
# of           <--prep      -- Cause
# death        <--compound  -- Party
# 	            <--dep       -- death
# Heart        <--compound  -- Party
# attack       <--compound  -- Party
#
#             <--dep       -- attack
# Party        <--compound  -- Lalita
# 	            <--dep       -- Party
# Indian       <--compound  -- Lalita
# National     <--compound  -- Lalita
# Congress     <--compound  -- Lalita
#
#             <--dep       -- Congress
# Spouse       <--compound  -- Lalita
# 	            <--dep       -- Spouse
# Lalita       <--pobj      -- of
# Shastri      <--compound  -- ​(m
# ​(m          <--appos     -- Tashkent
# .            <--punct     -- Died
# 1928)​       <--compound  -- Children
#
#             <--dep       -- 1928)​
# Children     <--nsubj     -- is
# 	            <--dep       -- Children
# 6            <--nummod    -- Children
# ;            <--punct     -- Children
# including    <--prep      -- Children
# Anil         <--compound  -- Shastri
# Shastri      <--pobj      -- including
# ,            <--punct     -- Shastri
# Hari         <--compound  -- Krishna
# Krishna      <--compound  -- Shastri
# Shastri      <--conj      -- Shastri
# and          <--cc        -- Shastri
# Sunil        <--compound  -- Shastri
# Shastri      <--compound  -- Vidyapith
#
#             <--dep       -- Shastri
# Alma         <--compound  -- mater
# mater        <--compound  -- Vidyapith
# 	            <--dep       -- mater
# Mahatma      <--compound  -- Vidyapith
# Gandhi       <--compound  -- Vidyapith
# Kashi        <--compound  -- Vidyapith
# Vidyapith    <--nmod      -- article
# ,            <--punct     -- Vidyapith
# Varanasi     <--compound  -- Nickname
#
#             <--dep       -- Varanasi
# Profession   <--compound  -- Politician
# 	            <--dep       -- Profession
# Politician   <--compound  -- Nickname
#
#             <--dep       -- Politician
# Nickname     <--compound  -- Nanhe
# 	            <--dep       -- Nickname
# Nanhe        <--appos     -- Vidyapith
#
#
#           <--dep       -- Nanhe
# This         <--det       -- article
# article      <--conj      -- Shastri
# is           <--ROOT      -- is
# part         <--attr      -- is
# of           <--prep      -- part
#
#             <--dep       -- of
# a            <--det       -- series
# series       <--pobj      -- of
# about        <--prep      -- series
#
#             <--dep       -- about
# Lal          <--compound  -- Bahadur
# Bahadur      <--pobj      -- about
# Shastri      <--compound  -- Minister
#
#             <--dep       -- Shastri
# Prime        <--compound  -- Minister
# Minister     <--appos     -- Bahadur
# of           <--prep      -- Minister
# India        <--pobj      -- of
#
#             <--dep       -- India
# (            <--punct     -- 1964–1966
# 1964–1966    <--appos     -- Minister
# )            <--punct     -- 1964–1966
#
#             <--dep       -- )
# Early        <--amod      -- life
# life         <--nsubj     -- educationGandhi
# and          <--cc        -- life
# educationGandhi <--ROOT      -- educationGandhi
# 's           <--case      -- educationGandhi
# discipleJai  <--nsubj     -- educationGandhi
# Jawan        <--compound  -- KisanDeath
# Jai          <--compound  -- KisanDeath
# KisanDeath   <--attr      -- educationGandhi
# and          <--cc        -- KisanDeath
# state        <--compound  -- funeralEponyms
# funeralEponyms <--nmod      -- Council
#
#             <--dep       -- funeralEponyms
# Premiership  <--compound  -- Council
#
#
#            <--dep       -- Premiership
# Union        <--compound  -- Council
# Council      <--conj      -- KisanDeath
# of           <--prep      -- Council
# Ministers    <--compound  -- ShastriLok
# ShastriLok   <--pobj      -- of
# Sabha        <--nmod      -- ThirdDomestic
# ThirdDomestic <--nmod      -- policies
# policiesEconomic <--amod      -- policiesForeign
# policiesForeign <--amod      -- policies
# policies     <--ROOT      -- policies
#
#             <--dep       -- policies
# Constitutional <--amod      -- amendments
# amendments   <--appos     -- policies
#
#
#            <--dep       -- amendments
# 18th19th20th <--punct     -- amendments
#
#             <--dep       -- 18th19th20th
# Events       <--pobj      -- 18th19th20th
#
#
#            <--dep       -- Events
# White        <--compound  -- RevolutionSirima
# RevolutionSirima <--appos     -- amendments
# –            <--punct     -- RevolutionSirima
# Shastri      <--compound  -- War
# PactIndo     <--compound  -- Pakistani
# -            <--punct     -- Pakistani
# Pakistani    <--compound  -- War
# War          <--appos     -- RevolutionSirima
# of           <--prep      -- War
# 1965         <--nummod    -- Gallery
# Tashkent     <--compound  -- Declaration
# Declaration  <--compound  -- Lalita
#
#             <--dep       -- Declaration
# Lalita       <--compound  -- Jawaan
# ShastriJai   <--compound  -- Jawaan
# Jawaan       <--compound  -- Gallery
# Jai          <--compound  -- Gallery
# KisaanThe    <--compound  -- Gallery
# Tashkent     <--compound  -- Gallery
# Files        <--compound  -- Gallery
#
#             <--dep       -- Files
# Gallery      <--pobj      -- of
# :            <--punct     -- policies
# Picture      <--nsubj     -- was
# ,            <--punct     -- Picture
# Sound        <--conj      -- Picture
# ,            <--punct     -- Sound
# Video        <--compound  -- vte
#
#             <--dep       -- Video
# vte          <--conj      -- Sound
#
#             <--dep       -- vte
# Lal          <--compound  -- Bahadur
# Bahadur      <--compound  -- Shastri[c
# Shastri[c    <--appos     -- Picture
# ]            <--punct     -- Picture
# (            <--punct     -- Picture
# 2            <--appos     -- Picture
# October      <--appos     -- Picture
# 1904         <--nummod    -- October
# –            <--punct     -- Picture
# 11           <--appos     -- Picture
# January      <--npadvmod  -- Picture
# 1966         <--nummod    -- January
# )            <--punct     -- Picture
# was          <--ROOT      -- was
# an           <--det       -- politician
# Indian       <--amod      -- politician
# politician   <--attr      -- was
# and          <--cc        -- politician
# statesman    <--conj      -- politician
# who          <--nsubj     -- served
# served       <--relcl     -- politician
# as           <--prep      -- served
# the          <--det       -- minister
# prime        <--amod      -- minister
# minister     <--pobj      -- as
# of           <--prep      -- minister
# India        <--pobj      -- of
# from         <--prep      -- served
# 1964         <--pobj      -- from
# to           <--prep      -- from
# 1966         <--pobj      -- to
# .            <--punct     -- was
# He           <--nsubj     -- served
# previously   <--advmod    -- served
# served       <--ROOT      -- served
# as           <--prep      -- served
# home         <--compound  -- minister
# minister     <--pobj      -- as
# from         <--prep      -- served
# 1961         <--pobj      -- from
# to           <--prep      -- from
# 1963         <--pobj      -- to
# .            <--punct     -- served
#
#
#            <--dep       -- .
# Shastri      <--nsubjpass -- born
# was          <--auxpass   -- born
# born         <--ROOT      -- born
# to           <--prep      -- born
# Sharad       <--compound  -- Srivastava
# Prasad       <--compound  -- Srivastava
# Srivastava   <--pobj      -- to
# and          <--cc        -- Srivastava
# Ramdulari    <--compound  -- Devi
# Devi         <--conj      -- Srivastava
# in           <--prep      -- Srivastava
# Mughalsarai  <--pobj      -- in
# on           <--prep      -- born
# 2            <--nummod    -- October
# October      <--pobj      -- on
# 1904         <--nummod    -- October
# .            <--punct     -- born
# He           <--nsubj     -- studied
# studied      <--ROOT      -- studied
# in           <--prep      -- studied
# East         <--compound  -- Central
# Central      <--compound  -- college
# Railway      <--compound  -- college
# Inter        <--compound  -- college
# college      <--pobj      -- in
# and          <--cc        -- college
# the          <--det       -- School
# Harish       <--compound  -- School
# Chandra      <--compound  -- School
# High         <--compound  -- School
# School       <--conj      -- college
# ,            <--punct     -- School
# which        <--dobj      -- left
# he           <--nsubj     -- left
# left         <--relcl     -- School
# to           <--aux       -- join
# join         <--xcomp     -- left
# the          <--det       -- movement
# non          <--amod      -- movement
# -            <--amod      -- movement
# cooperation  <--amod      -- movement
# movement     <--dobj      -- join
# .            <--punct     -- studied
# He           <--nsubj     -- worked
# worked       <--ROOT      -- worked
# for          <--prep      -- worked
# the          <--det       -- betterment
# betterment   <--pobj      -- for
# of           <--prep      -- betterment
# the          <--det       -- Harijans
# Harijans     <--pobj      -- of
# at           <--prep      -- worked
# Muzaffarpur  <--pobj      -- at
# and          <--cc        -- worked
# dropped      <--conj      -- worked
# his          <--poss      -- surname
# caste        <--npadvmod  -- derived
# -            <--punct     -- derived
# derived      <--amod      -- surname
# surname      <--dobj      -- dropped
# of           <--prep      -- surname
# "            <--punct     -- Srivastava
# Srivastava   <--pobj      -- of
# "            <--punct     -- Srivastava
# .            <--punct     -- worked
# Influenced   <--advcl     -- joined
# by           <--agent     -- Influenced
# Mahatma      <--compound  -- Gandhi
# Gandhi       <--pobj      -- by
# ,            <--punct     -- joined
# he           <--nsubj     -- joined
# joined       <--ROOT      -- joined
# the          <--det       -- movement
# Indian       <--amod      -- Independence
# Independence <--compound  -- movement
# movement     <--dobj      -- joined
# in           <--prep      -- joined
# the          <--det       -- 1920s
# 1920s        <--pobj      -- in
# .            <--punct     -- joined
# He           <--nsubj     -- served
# served       <--ROOT      -- served
# as           <--prep      -- served
# the          <--det       -- president
# president    <--pobj      -- as
# of           <--prep      -- president
# Servants     <--pobj      -- of
# of           <--prep      -- Servants
# the          <--det       -- Society
# People       <--compound  -- Society
# Society      <--pobj      -- of
# ,            <--punct     -- served
# founded      <--advcl     -- served
# by           <--agent     -- founded
# Lala         <--compound  -- Lajpat
# Lajpat       <--compound  -- Rai
# Rai          <--pobj      -- by
# and          <--cc        -- founded
# held         <--conj      -- founded
# prominent    <--amod      -- positions
# positions    <--dobj      -- held
# in           <--prep      -- positions
# the          <--det       -- Congress
# Indian       <--compound  -- Congress
# National     <--compound  -- Congress
# Congress     <--pobj      -- in
# (            <--punct     -- Congress
# INC          <--appos     -- Congress
# )            <--punct     -- Congress
# .            <--punct     -- served
# Following    <--prep      -- led
# Indian       <--amod      -- independence
# independence <--pobj      -- Following
# in           <--prep      -- independence
# 1947         <--pobj      -- in
# ,            <--punct     -- led
# Shastri      <--nsubj     -- led
# led          <--ROOT      -- led
# several      <--amod      -- ministries
# union        <--compound  -- ministries
# ministries   <--dobj      -- led
# under        <--prep      -- led
# prime        <--compound  -- minister
# minister     <--compound  -- Nehru
# Jawaharlal   <--compound  -- Nehru
# Nehru        <--pobj      -- under
# .            <--punct     -- led
#
#
#            <--dep       -- .
# As           <--prep      -- promoted
# prime        <--amod      -- minister
# minister     <--pobj      -- As
# ,            <--punct     -- promoted
# Shastri      <--nsubj     -- promoted
# promoted     <--ROOT      -- promoted
# the          <--det       -- revolution
# White        <--compound  -- revolution
# revolution   <--dobj      -- promoted
# (            <--punct     -- revolution
# India        <--appos     -- revolution
# )            <--punct     -- revolution
# ,            <--punct     -- revolution
# a            <--det       -- campaign
# national     <--amod      -- campaign
# campaign     <--appos     -- revolution
# to           <--aux       -- increase
# increase     <--acl       -- campaign
# the          <--det       -- production
# production   <--dobj      -- increase
# and          <--cc        -- production
# supply       <--conj      -- production
# of           <--prep      -- production
# milk         <--pobj      -- of
# ,            <--punct     -- revolution
# by           <--prep      -- promoted
# supporting   <--pcomp     -- by
# the          <--det       -- milk
# Amul         <--compound  -- milk
# milk         <--dobj      -- supporting
# co           <--oprd      -- supporting
# -            <--dobj      -- supporting
# operative    <--acomp     -- supporting
# and          <--cc        -- supporting
# creating     <--conj      -- supporting
# the          <--det       -- Board
# National     <--compound  -- Board
# Dairy        <--compound  -- Board
# Development  <--compound  -- Board
# Board        <--dobj      -- creating
# .            <--punct     -- promoted
# Underlining  <--advcl     -- promoted
# the          <--det       -- need
# need         <--dobj      -- Underlining
# to           <--aux       -- boost
# boost        <--acl       -- need
# India        <--poss      -- production
# 's           <--case      -- India
# food         <--compound  -- production
# production   <--dobj      -- boost
# ,            <--punct     -- promoted
# Shastri      <--nsubj     -- promoted
# also         <--advmod    -- promoted
# promoted     <--ROOT      -- promoted
# the          <--det       -- Revolution
# Green        <--compound  -- Revolution
# Revolution   <--dobj      -- promoted
# in           <--prep      -- Revolution
# India        <--pobj      -- in
# in           <--prep      -- promoted
# 1965         <--pobj      -- in
# .            <--punct     -- promoted
# This         <--nsubj     -- led
# led          <--ROOT      -- led
# to           <--prep      -- led
# an           <--det       -- increase
# increase     <--pobj      -- to
# in           <--prep      -- increase
# food         <--compound  -- grain
# grain        <--compound  -- production
# production   <--pobj      -- in
# ,            <--punct     -- led
# especially   <--advmod    -- in
# in           <--prep      -- led
# the          <--det       -- states
# states       <--pobj      -- in
# of           <--prep      -- states
# Punjab       <--pobj      -- of
# ,            <--punct     -- Punjab
# Haryana      <--conj      -- Punjab
# and          <--cc        -- Haryana
# Uttar        <--compound  -- Pradesh
# Pradesh      <--conj      -- Haryana
# .            <--punct     -- led
# He           <--nsubj     -- led
# led          <--ROOT      -- led
# the          <--det       -- country
# country      <--dobj      -- led
# during       <--prep      -- led
# the          <--det       -- war
# Indo         <--compound  -- Pakistani
# -            <--punct     -- Pakistani
# Pakistani    <--amod      -- war
# war          <--pobj      -- during
# of           <--prep      -- war
# 1965         <--pobj      -- of
# .            <--punct     -- led
# His          <--poss      -- slogan
# slogan       <--nsubj     -- became
# "            <--punct     -- slogan
# Jai          <--compound  -- Jawan
# Jawan        <--appos     -- slogan
# ,            <--punct     -- Jawan
# Jai          <--compound  -- Kisan
# Kisan        <--appos     -- Jawan
# "            <--punct     -- slogan
# (            <--punct     -- Hail
# "            <--punct     -- Hail
# Hail         <--nsubj     -- became
# to           <--prep      -- Hail
# the          <--det       -- soldier
# soldier      <--pobj      -- to
# ;            <--punct     -- Hail
# Hail         <--appos     -- Hail
# to           <--prep      -- Hail
# the          <--det       -- farmer
# farmer       <--pobj      -- to
# "            <--punct     -- Hail
# )            <--punct     -- Hail
# became       <--ROOT      -- became
# very         <--advmod    -- popular
# popular      <--acomp     -- became
# during       <--prep      -- became
# the          <--det       -- war
# war          <--pobj      -- during
# .            <--punct     -- became
# The          <--det       -- war
# war          <--nsubj     -- ended
# formally     <--advmod    -- ended
# ended        <--ccomp     -- died
# with         <--prep      -- ended
# the          <--det       -- Declaration
# Tashkent     <--compound  -- Declaration
# Declaration  <--pobj      -- with
# on           <--prep      -- ended
# 10           <--nummod    -- January
# January      <--pobj      -- on
# 1966         <--nummod    -- January
# ;            <--punct     -- died
# Shastri      <--nsubj     -- died
# died         <--ROOT      -- died
# the          <--det       -- day
# next         <--amod      -- day
# day          <--npadvmod  -- died
# .            <--punct     -- died
#
#
#            <--dep       -- .
# Early        <--amod      -- years
# years        <--npadvmod  -- born
# (            <--punct     -- years
# 1904–1920    <--appos     -- years
# )            <--punct     -- years
#
#             <--dep       -- )
# Shastri      <--nsubjpass -- born
# was          <--auxpass   -- born
# born         <--ROOT      -- born
# on           <--prep      -- born
# 2            <--nummod    -- October
# October      <--pobj      -- on
# 1904         <--nummod    -- October
# at           <--prep      -- born
# the          <--det       -- home
# home         <--pobj      -- at
# of           <--prep      -- home
# his          <--poss      -- grandparents.[1][2
# maternal     <--amod      -- grandparents.[1][2
# grandparents.[1][2 <--pobj      -- of
# ]            <--punct     -- born
# Shastri      <--poss      -- ancestors
# 's           <--case      -- Shastri
# paternal     <--amod      -- ancestors
# ancestors    <--nsubj     -- were
# were         <--ROOT      -- were
# in           <--prep      -- were
# the          <--det       -- service
# service      <--pobj      -- in
# of           <--prep      -- service
# the          <--det       -- zamindar
# zamindar     <--pobj      -- of
# of           <--prep      -- zamindar
# Ramnagar     <--pobj      -- of
# in           <--prep      -- Ramnagar
# Banaras      <--pobj      -- in
# ,            <--punct     -- were
# and          <--cc        -- were
# Shastri      <--nsubj     -- lived
# lived        <--conj      -- were
# there        <--advmod    -- lived
# for          <--prep      -- lived
# the          <--det       -- year
# first        <--amod      -- year
# year         <--pobj      -- for
# of           <--prep      -- year
# his          <--poss      -- life
# life         <--pobj      -- of
# .            <--punct     -- lived
# Shastri      <--poss      -- father
# 's           <--case      -- Shastri
# father       <--nsubj     -- was
# ,            <--punct     -- father
# Sharad       <--compound  -- Srivastava
# Prasad       <--compound  -- Srivastava
# Srivastava   <--appos     -- father
# ,            <--punct     -- father
# was          <--ROOT      -- was
# a            <--det       -- teacher
# school       <--compound  -- teacher
# teacher      <--attr      -- was
# who          <--nsubj     -- became
# later        <--advmod    -- became
# became       <--relcl     -- teacher
# a            <--det       -- clerk
# clerk        <--attr      -- became
# in           <--prep      -- clerk
# the          <--det       -- office
# revenue      <--compound  -- office
# office       <--pobj      -- in
# at           <--prep      -- became
# Prayagraj    <--pobj      -- at
# ,            <--punct     -- was
# while        <--mark      -- was
# his          <--poss      -- mother
# mother       <--nsubj     -- was
# ,            <--punct     -- mother
# Ramdulari    <--compound  -- Devi
# Devi         <--appos     -- mother
# ,            <--punct     -- mother
# was          <--advcl     -- was
# the          <--det       -- daughter
# daughter     <--attr      -- was
# of           <--prep      -- daughter
# Munshi       <--compound  -- Hazari
# Hazari       <--compound  -- Lal
# Lal          <--pobj      -- of
# ,            <--punct     -- Lal
# the          <--det       -- headmaster
# headmaster   <--appos     -- Lal
# and          <--cc        -- headmaster
# English      <--amod      -- teacher
# teacher      <--conj      -- headmaster
# at           <--prep      -- headmaster
# a            <--det       -- school
# railway      <--compound  -- school
# school       <--pobj      -- at
# in           <--prep      -- school
# Mughalsarai  <--pobj      -- in
# .            <--punct     -- was
# Shastri      <--nsubj     -- was
# was          <--ccomp     -- had
# the          <--det       -- child
# second       <--amod      -- child
# child        <--attr      -- was
# and          <--cc        -- child
# eldest       <--amod      -- son
# son          <--conj      -- child
# of           <--prep      -- son
# his          <--poss      -- parents
# parents      <--pobj      -- of
# ;            <--punct     -- had
# he           <--nsubj     -- had
# had          <--ROOT      -- had
# an           <--det       -- sister
# elder        <--amod      -- sister
# sister       <--dobj      -- had
# ,            <--punct     -- sister
# Kailashi     <--compound  -- Devi
# Devi         <--appos     -- sister
# (            <--punct     -- Devi
# b.           <--compound  -- 1900).[3][4
# 1900).[3][4  <--appos     -- Devi
# ]            <--punct     -- Devi
#
#
#            <--dep       -- ]
# In           <--prep      -- died
# April        <--pobj      -- In
# 1905         <--nummod    -- April
# ,            <--punct     -- April
# when         <--advmod    -- was
# Shastri      <--nsubj     -- was
# was          <--relcl     -- April
# hardly       <--advmod    -- 18
# 18           <--nummod    -- months
# months       <--npadvmod  -- old
# old          <--acomp     -- was
# ,            <--punct     -- died
# his          <--poss      -- father
# father       <--nsubj     -- died
# ,            <--punct     -- father
# who          <--nsubjpass -- promoted
# had          <--aux       -- promoted
# recently     <--advmod    -- promoted
# been         <--auxpass   -- promoted
# promoted     <--relcl     -- father
# to           <--prep      -- promoted
# the          <--det       -- post
# post         <--pobj      -- to
# of           <--prep      -- post
# deputy       <--compound  -- tehsildar
# tehsildar    <--pobj      -- of
# ,            <--punct     -- father
# died         <--conj      -- had
# in           <--prep      -- died
# an           <--det       -- epidemic
# epidemic     <--pobj      -- in
# of           <--prep      -- epidemic
# bubonic      <--compound  -- plague
# plague       <--pobj      -- of
# .            <--punct     -- died
# Ramdulari    <--compound  -- Devi
# Devi         <--nsubj     -- took
# ,            <--punct     -- Devi
# then         <--advmod    -- old
# only         <--advmod    -- 23
# 23           <--nummod    -- years
# years        <--npadvmod  -- old
# old          <--amod      -- Devi
# and          <--cc        -- old
# pregnant     <--conj      -- old
# with         <--prep      -- pregnant
# her          <--poss      -- child
# third        <--amod      -- child
# child        <--pobj      -- with
# ,            <--punct     -- Devi
# took         <--ROOT      -- took
# her          <--poss      -- children
# two          <--nummod    -- children
# children     <--dobj      -- took
# and          <--cc        -- took
# moved        <--conj      -- took
# from         <--prep      -- moved
# Ramnagar     <--pobj      -- from
# to           <--prep      -- moved
# her          <--poss      -- father
# father       <--poss      -- house
# 's           <--case      -- father
# house        <--pobj      -- to
# in           <--prep      -- house
# Mughalsarai  <--pobj      -- in
# and          <--cc        -- moved
# settled      <--conj      -- moved
# there        <--advmod    -- settled
# for          <--prep      -- settled
# good         <--pobj      -- for
# .            <--punct     -- took
# She          <--nsubj     -- gave
# gave         <--ROOT      -- gave
# birth        <--dobj      -- gave
# to           <--prep      -- gave
# a            <--det       -- daughter
# daughter     <--pobj      -- to
# ,            <--punct     -- daughter
# Sundari      <--compound  -- Devi
# Devi         <--appos     -- daughter
# ,            <--punct     -- daughter
# in           <--prep      -- gave
# July         <--compound  -- 1906.[5][6
# 1906.[5][6   <--pobj      -- in
# ]            <--punct     -- gave
# Thus         <--advmod    -- grew
# ,            <--punct     -- grew
# Shastri      <--nsubj     -- grew
# and          <--cc        -- Shastri
# his          <--poss      -- sisters
# sisters      <--conj      -- Shastri
# grew         <--ccomp     -- died
# up           <--prt       -- grew
# in           <--prep      -- grew
# the          <--det       -- household
# household    <--pobj      -- in
# of           <--prep      -- household
# his          <--poss      -- grandfather
# maternal     <--amod      -- grandfather
# grandfather  <--pobj      -- of
# ,            <--punct     -- grandfather
# Hazari       <--compound  -- Lalji.[7
# Lalji.[7     <--appos     -- grandfather
# ]            <--punct     -- grew
# However      <--advmod    -- died
# ,            <--punct     -- died
# Hazari       <--compound  -- Lalji
# Lalji        <--nsubj     -- died
# himself      <--appos     -- Lalji
# died         <--ROOT      -- died
# from         <--prep      -- died
# a            <--det       -- stroke
# stroke       <--pobj      -- from
# in           <--prep      -- died
# mid-1908     <--pobj      -- in
# .            <--punct     -- died
# Thereafter   <--advmod    -- looked
# ,            <--punct     -- looked
# the          <--det       -- family
# family       <--nsubjpass -- looked
# was          <--auxpass   -- looked
# looked       <--advcl     -- was
# after        <--prep      -- looked
# by           <--agent     -- looked
# his          <--poss      -- brother
# brother      <--pobj      -- by
# (            <--punct     -- uncle
# Shastri      <--poss      -- uncle
# 's           <--case      -- Shastri
# great        <--amod      -- uncle
# -            <--punct     -- uncle
# uncle        <--appos     -- brother
# )            <--punct     -- uncle
# Darbari      <--compound  -- Lal
# Lal          <--nsubj     -- was
# ,            <--punct     -- Lal
# who          <--nsubj     -- was
# was          <--relcl     -- Lal
# the          <--det       -- clerk
# head         <--compound  -- clerk
# clerk        <--attr      -- was
# in           <--prep      -- clerk
# the          <--det       -- department
# opium        <--compound  -- regulation
# regulation   <--compound  -- department
# department   <--pobj      -- in
# at           <--prep      -- was
# Ghazipur     <--pobj      -- at
# ,            <--punct     -- Lal
# and          <--cc        -- Lal
# later        <--advmod    -- by
# by           <--conj      -- Lal
# his          <--poss      -- son
# son          <--pobj      -- by
# (            <--punct     -- son
# Ramdulari    <--compound  -- Devi
# Devi         <--poss      -- cousin
# 's           <--case      -- Devi
# cousin       <--appos     -- son
# )            <--punct     -- son
# Bindeshwari  <--compound  -- Prasad
# Prasad       <--appos     -- son
# ,            <--punct     -- Prasad
# a            <--det       -- teacher
# school       <--compound  -- teacher
# teacher      <--appos     -- Prasad
# in           <--prep      -- teacher
# Mughalsarai.[8 <--pobj      -- in
# ]            <--punct     -- Prasad
#
#
#            <--dep       -- ]
# This         <--det       -- situation
# situation    <--nsubj     -- was
# was          <--ccomp     -- was
# standard     <--acomp     -- was
# for          <--prep      -- standard
# the          <--det       -- time
# time         <--pobj      -- for
# ,            <--punct     -- time
# where        <--advmod    -- was
# the          <--det       -- system
# Indian       <--amod      -- system
# joint        <--amod      -- family
# family       <--compound  -- system
# system       <--nsubj     -- was
# was          <--relcl     -- time
# a            <--det       -- reality
# thriving     <--amod      -- reality
# reality      <--attr      -- was
# ;            <--punct     -- was
# the          <--det       -- sense
# sense        <--nsubj     -- was
# of           <--prep      -- sense
# family       <--compound  -- relationship
# relationship <--pobj      -- of
# and          <--cc        -- relationship
# responsibility <--conj      -- relationship
# it           <--nsubj     -- fostered
# fostered     <--relcl     -- sense
# was          <--ROOT      -- was
# the          <--det       -- security
# primary      <--amod      -- security
# social       <--amod      -- security
# security     <--attr      -- was
# of           <--prep      -- security
# the          <--det       -- time
# time         <--pobj      -- of
# .            <--punct     -- was
# Nor          <--cc        -- surmised
# should       <--aux       -- surmised
# it           <--nsubjpass -- surmised
# be           <--auxpass   -- surmised
# surmised     <--ROOT      -- surmised
# from         <--prep      -- surmised
# these        <--det       -- circumstances
# circumstances <--pobj      -- from
# that         <--mark      -- grew
# Shastri      <--nsubj     -- grew
# grew         <--relcl     -- circumstances
# up           <--prt       -- grew
# in           <--prep      -- grew
# an           <--det       -- manner
# under        <--advmod    -- privileged
# -            <--punct     -- privileged
# privileged   <--amod      -- manner
# manner       <--pobj      -- in
# ,            <--punct     -- grew
# or           <--cc        -- grew
# that         <--mark      -- compromised
# his          <--poss      -- education
# education    <--nsubjpass -- compromised
# and          <--cc        -- education
# comforts     <--conj      -- education
# were         <--auxpass   -- compromised
# compromised  <--conj      -- grew
# .            <--punct     -- surmised
# On           <--prep      -- received
# the          <--det       -- contrary
# contrary     <--pobj      -- On
# ,            <--punct     -- received
# since        <--mark      -- was
# he           <--nsubj     -- was
# was          <--advcl     -- received
# a            <--det       -- student
# rank         <--compound  -- student
# student      <--attr      -- was
# ,            <--punct     -- received
# he           <--nsubj     -- received
# received     <--ROOT      -- received
# a            <--det       -- education
# better       <--amod      -- education
# education    <--dobj      -- received
# than         <--prep      -- education
# some         <--pobj      -- than
# of           <--prep      -- some
# his          <--poss      -- cousins.[9
# cousins.[9   <--pobj      -- of
# ]            <--punct     -- received
# Bindeshwari  <--compound  -- Prasad
# Prasad       <--dobj      -- received
# ,            <--punct     -- received
# on           <--prep      -- received
# the          <--det       -- salary
# limited      <--amod      -- salary
# salary       <--pobj      -- on
# of           <--prep      -- salary
# a            <--det       -- teacher
# school       <--compound  -- teacher
# teacher      <--pobj      -- of
# ,            <--punct     -- received
# with         <--prep      -- managed
# many         <--amod      -- dependents
# dependents   <--pobj      -- with
# ,            <--punct     -- managed
# nevertheless <--advmod    -- managed
# managed      <--advcl     -- received
# to           <--aux       -- give
# give         <--xcomp     -- managed
# a            <--det       -- education
# good         <--amod      -- education
# education    <--dobj      -- give
# to           <--dative    -- give
# all          <--predet    -- children
# the          <--det       -- children
# children     <--pobj      -- to
# in           <--prep      -- give
# his          <--poss      -- care
# care         <--pobj      -- in
# .            <--punct     -- received
#
#
#            <--dep       -- .
# In           <--prep      -- transferred
# 1917         <--pobj      -- In
# ,            <--punct     -- transferred
# Bindeshwari  <--compound  -- Prasad
# Prasad       <--nsubjpass -- transferred
# was          <--auxpass   -- transferred
# transferred  <--ROOT      -- transferred
# to           <--prep      -- transferred
# Varanasi     <--pobj      -- to
# ,            <--punct     -- transferred
# and          <--cc        -- transferred
# the          <--det       -- family
# entire       <--amod      -- family
# family       <--nsubj     -- moved
# moved        <--conj      -- transferred
# there        <--advmod    -- moved
# ,            <--punct     -- moved
# including    <--prep      -- family
# Ramdulari    <--compound  -- Devi
# Devi         <--pobj      -- including
# and          <--cc        -- Devi
# her          <--poss      -- children
# three        <--nummod    -- children
# children     <--conj      -- Devi
# .            <--punct     -- transferred
# In           <--prep      -- joining
# Varanasi     <--pobj      -- In
# ,            <--punct     -- joining
# Shastri      <--nsubj     -- joining
# joining      <--ROOT      -- joining
# the          <--det       -- standard
# seventh      <--amod      -- standard
# standard     <--dobj      -- joining
# at           <--prep      -- standard
# Harish       <--compound  -- School
# Chandra      <--compound  -- School
# High         <--compound  -- School
# School       <--pobj      -- at
# .            <--punct     -- joining
#
#
#            <--dep       -- .
# Early        <--amod      -- activities
# activities   <--nsubj     -- was
# (            <--punct     -- activities
# 1921–1945    <--appos     -- activities
# )            <--punct     -- activities
#
#             <--dep       -- )
# While        <--mark      -- had
# his          <--poss      -- family
# family       <--nsubj     -- had
# had          <--advcl     -- was
# no           <--det       -- links
# links        <--dobj      -- had
# to           <--prep      -- links
# the          <--det       -- movement
# independence <--compound  -- movement
# movement     <--pobj      -- to
# then         <--advmod    -- taking
# taking       <--advcl     -- had
# shape        <--dobj      -- taking
# ,            <--punct     -- had
# among        <--prep      -- had
# his          <--poss      -- teachers
# teachers     <--pobj      -- among
# at           <--prep      -- teachers
# Harish       <--compound  -- School
# Chandra      <--compound  -- School
# High         <--compound  -- School
# School       <--pobj      -- at
# was          <--ROOT      -- was
# an           <--det       -- teacher
# intensely    <--advmod    -- patriotic
# patriotic    <--amod      -- teacher
# and          <--cc        -- patriotic
# highly       <--advmod    -- respected
# respected    <--conj      -- patriotic
# teacher      <--attr      -- was
# named        <--acl       -- teacher
# Nishkameshwar <--compound  -- Mishra
# Prasad       <--compound  -- Mishra
# Mishra       <--oprd      -- named
# ,            <--punct     -- Mishra
# who          <--nsubj     -- gave
# gave         <--relcl     -- Mishra
# Shastri      <--nmod      -- support
# much         <--advmod    -- needed
# -            <--punct     -- needed
# needed       <--amod      -- support
# financial    <--amod      -- support
# support      <--dobj      -- gave
# by           <--prep      -- gave
# allowing     <--pcomp     -- by
# him          <--nsubj     -- tutor
# to           <--aux       -- tutor
# tutor        <--ccomp     -- allowing
# his          <--poss      -- children
# children     <--dobj      -- tutor
# .            <--punct     -- was
# Inspired     <--advcl     -- took
# by           <--agent     -- Inspired
# Mishra       <--poss      -- patriotism
# 's           <--case      -- Mishra
# patriotism   <--pobj      -- by
# ,            <--punct     -- took
# Shastri      <--nsubj     -- took
# took         <--ROOT      -- took
# a            <--det       -- interest
# deep         <--amod      -- interest
# interest     <--dobj      -- took
# in           <--prep      -- interest
# the          <--det       -- struggle
# freedom      <--compound  -- struggle
# struggle     <--pobj      -- in
# ,            <--punct     -- took
# and          <--cc        -- took
# began        <--conj      -- took
# to           <--aux       -- study
# study        <--xcomp     -- began
# its          <--poss      -- history
# history      <--dobj      -- study
# and          <--cc        -- history
# the          <--det       -- works
# works        <--conj      -- history
# of           <--prep      -- works
# several      <--pobj      -- of
# of           <--prep      -- several
# its          <--poss      -- personalities
# noted        <--amod      -- personalities
# personalities <--pobj      -- of
# ,            <--punct     -- personalities
# including    <--prep      -- personalities
# those        <--pobj      -- including
# of           <--prep      -- those
# Swami        <--compound  -- Vivekananda
# Vivekananda  <--pobj      -- of
# ,            <--punct     -- Vivekananda
# Mahatma      <--compound  -- Gandhi
# Gandhi       <--conj      -- Vivekananda
# and          <--cc        -- Gandhi
# Annie        <--compound  -- Besant.[citation
# Besant.[citation <--conj      -- Gandhi
# needed       <--conj      -- took
# ]            <--punct     -- needed
# In           <--prep      -- attended
# January      <--pobj      -- In
# 1921         <--nummod    -- January
# ,            <--punct     -- January
# when         <--advmod    -- was
# Shastri      <--nsubj     -- was
# was          <--advcl     -- attended
# in           <--prep      -- was
# the          <--det       -- standard
# 10th         <--amod      -- standard
# standard     <--pobj      -- in
# and          <--cc        -- standard
# three        <--nummod    -- months
# months       <--conj      -- standard
# from         <--prep      -- was
# sitting      <--pcomp     -- from
# the          <--det       -- examinations
# final        <--amod      -- examinations
# examinations <--dobj      -- sitting
# ,            <--punct     -- attended
# he           <--nsubj     -- attended
# attended     <--ROOT      -- attended
# a            <--det       -- meeting
# public       <--amod      -- meeting
# meeting      <--dobj      -- attended
# in           <--prep      -- meeting
# Benares      <--pobj      -- in
# hosted       <--acl       -- meeting
# by           <--agent     -- hosted
# Gandhi       <--nmod      -- Malaviya
# and          <--cc        -- Gandhi
# Pandit       <--conj      -- Gandhi
# Madan        <--compound  -- Malaviya
# Mohan        <--compound  -- Malaviya
# Malaviya     <--pobj      -- by
# .            <--punct     -- attended
# Inspired     <--advcl     -- withdrew
# by           <--agent     -- Inspired
# the          <--det       -- Mahatma
# Mahatma      <--poss      -- call
# 's           <--case      -- Mahatma
# call         <--pobj      -- by
# for          <--mark      -- withdraw
# students     <--nsubj     -- withdraw
# to           <--aux       -- withdraw
# withdraw     <--advcl     -- Inspired
# from         <--prep      -- withdraw
# government   <--compound  -- schools
# schools      <--pobj      -- from
# and          <--cc        -- withdraw
# join         <--conj      -- withdraw
# the          <--det       -- movement
# non          <--amod      -- movement
# -            <--amod      -- movement
# cooperation  <--amod      -- movement
# movement     <--dobj      -- join
# ,            <--punct     -- withdrew
# Shastri      <--nsubj     -- withdrew
# withdrew     <--ROOT      -- withdrew
# from         <--prep      -- withdrew
# Harish       <--compound  -- School
# Chandra      <--compound  -- School
# High         <--compound  -- School
# School       <--pobj      -- from
# the          <--det       -- day
# next         <--amod      -- day
# day          <--npadvmod  -- withdrew
# and          <--cc        -- withdrew
# joined       <--conj      -- withdrew
# the          <--det       -- branch
# local        <--amod      -- branch
# branch       <--dobj      -- joined
# of           <--prep      -- branch
# the          <--det       -- Party
# Congress     <--compound  -- Party
# Party        <--pobj      -- of
# as           <--prep      -- joined
# a            <--det       -- volunteer
# volunteer    <--pobj      -- as
# ,            <--punct     -- joined
# actively     <--advmod    -- participating
# participating <--advcl     -- joined
# in           <--prep      -- participating
# picketing    <--pobj      -- in
# and          <--cc        -- picketing
# anti         <--amod      -- demonstrations.[10
# -            <--amod      -- demonstrations.[10
# government   <--amod      -- demonstrations.[10
# demonstrations.[10 <--conj      -- picketing
# ]            <--punct     -- withdrew
# He           <--nsubjpass -- arrested
# was          <--auxpass   -- arrested
# soon         <--advmod    -- arrested
# arrested     <--ROOT      -- arrested
# and          <--cc        -- arrested
# ...
# in           <--prep      -- interested
# knowing      <--pcomp     -- in
# the          <--det       -- success
# success      <--dobj      -- knowing
# of           <--prep      -- success
# this         <--det       -- co
# co           <--pobj      -- of
# -            <--pobj      -- of
# operative    <--oprd      -- knowing
# ,            <--punct     -- stayed
# he           <--nsubj     -- stayed
# stayed       <--ROOT      -- stayed
# overnight    <--advmod    -- stayed
# with         <--prep      -- stayed
# farmers      <--pobj      -- with
# in           <--prep      -- farmers
# a            <--det       -- village
# village      <--pobj      -- in
# ,            <--punct     -- stayed
# and          <--cc        -- stayed
# even         <--advmod    -- had
# had          <--conj      -- stayed
# dinner       <--dobj      -- had
# with         <--prep      -- dinner
# a            <--det       -- farmer
# farmer       <--poss      -- family
# 's           <--case      -- farmer
# family       <--pobj      -- with
# .            <--punct     -- stayed
# He           <--nsubj     -- discussed
# discussed    <--ROOT      -- discussed
# his          <--poss      -- wish
# wish         <--dobj      -- discussed
# with         <--prep      -- discussed
# Verghese     <--compound  -- Kurien
# Kurien       <--pobj      -- with
# ,            <--punct     -- Kurien
# then         <--advmod    -- Manager
# the          <--det       -- Manager
# General      <--compound  -- Manager
# Manager      <--appos     -- Kurien
# of           <--prep      -- Manager
# Kaira        <--compound  -- District
# District     <--compound  -- Co
# Co           <--compound  -- Ltd
# -            <--amod      -- Ltd
# operative    <--amod      -- Ltd
# Milk         <--compound  -- Producers
# Producers    <--poss      -- Ltd
# '            <--case      -- Producers
# Union        <--compound  -- Ltd
# Ltd          <--pobj      -- of
# (            <--punct     -- Ltd
# Amul         <--appos     -- Ltd
# )            <--punct     -- Kurien
# to           <--aux       -- replicate
# replicate    <--advcl     -- discussed
# this         <--det       -- model
# model        <--dobj      -- replicate
# to           <--prep      -- replicate
# other        <--amod      -- parts
# parts        <--pobj      -- to
# of           <--prep      -- parts
# the          <--det       -- country
# country      <--pobj      -- of
# for          <--prep      -- replicate
# improving    <--pcomp     -- for
# the          <--det       -- conditions
# socio        <--npadvmod  -- economic
# -            <--punct     -- economic
# economic     <--amod      -- conditions
# conditions   <--dobj      -- improving
# of           <--prep      -- conditions
# farmers      <--pobj      -- of
# .            <--punct     -- discussed
# As           <--prep      -- established
# a            <--det       -- result
# result       <--pobj      -- As
# of           <--prep      -- result
# this         <--det       -- visit
# visit        <--pobj      -- of
# ,            <--punct     -- established
# the          <--det       -- Board
# National     <--compound  -- Board
# Dairy        <--compound  -- Board
# Development  <--compound  -- Board
# Board        <--nsubjpass -- established
# (            <--punct     -- Board
# NDDB         <--appos     -- Board
# )            <--punct     -- Board
# was          <--auxpass   -- established
# established  <--ROOT      -- established
# at           <--prep      -- established
# Anand        <--pobj      -- at
# in           <--prep      -- established
# 1965.[40     <--pobj      -- in
# ]            <--punct     -- in
#
#
#            <--dep       -- ]
# While        <--mark      -- speaking
# speaking     <--advcl     -- urged
# on           <--prep      -- speaking
# the          <--det       -- shortages
# chronic      <--amod      -- shortages
# food         <--compound  -- shortages
# shortages    <--pobj      -- on
# across       <--prep      -- shortages
# the          <--det       -- country
# country      <--pobj      -- across
# ,            <--punct     -- urged
# Shastri      <--nsubj     -- urged
# urged        <--conj      -- established
# people       <--dobj      -- urged
# to           <--aux       -- give
# voluntarily  <--advmod    -- give
# give         <--xcomp     -- urged
# up           <--prt       -- give
# one          <--nummod    -- meal
# meal         <--dobj      -- give
# so           <--mark      -- distributed
# that         <--mark      -- distributed
# the          <--det       -- food
# food         <--nsubjpass -- distributed
# saved        <--acl       -- food
# could        <--aux       -- distributed
# be           <--auxpass   -- distributed
# distributed  <--advcl     -- give
# to           <--prep      -- distributed
# the          <--det       -- populace
# affected     <--amod      -- populace
# populace     <--pobj      -- to
# .            <--punct     -- established
# However      <--advmod    -- ensured
# ,            <--punct     -- ensured
# he           <--nsubj     -- ensured
# ensured      <--ROOT      -- ensured
# that         <--mark      -- implemented
# he           <--nsubj     -- implemented
# first        <--advmod    -- implemented
# implemented  <--ccomp     -- ensured
# the          <--det       -- system
# system       <--dobj      -- implemented
# in           <--prep      -- implemented
# his          <--poss      -- family
# own          <--amod      -- family
# family       <--pobj      -- in
# before       <--prep      -- implemented
# appealing    <--pcomp     -- before
# to           <--prep      -- appealing
# the          <--det       -- country
# country      <--pobj      -- to
# .            <--punct     -- ensured
# He           <--nsubj     -- went
# went         <--ROOT      -- went
# on           <--prep      -- went
# air          <--pobj      -- on
# to           <--aux       -- appeal
# appeal       <--advcl     -- went
# to           <--prep      -- appeal
# his          <--poss      -- countrymen
# countrymen   <--pobj      -- to
# to           <--aux       -- skip
# skip         <--advcl     -- appeal
# a            <--det       -- meal
# meal         <--dobj      -- skip
# a            <--det       -- week
# week         <--npadvmod  -- skip
# .            <--punct     -- went
# The          <--det       -- response
# response     <--nsubj     -- was
# to           <--prep      -- response
# his          <--poss      -- appeal
# appeal       <--pobj      -- to
# was          <--ROOT      -- was
# overwhelming <--acomp     -- was
# .            <--punct     -- was
# Even         <--advmod    -- restaurants
# restaurants  <--nsubj     -- downed
# and          <--cc        -- restaurants
# eateries     <--conj      -- restaurants
# downed       <--ROOT      -- downed
# the          <--det       -- shutters
# shutters     <--dobj      -- downed
# on           <--prep      -- downed
# Monday       <--compound  -- evenings
# evenings     <--pobj      -- on
# .            <--punct     -- downed
# Many         <--amod      -- parts
# parts        <--nsubj     -- observed
# of           <--prep      -- parts
# the          <--det       -- country
# country      <--pobj      -- of
# observed     <--ROOT      -- observed
# the          <--det       -- Vrat
# "            <--punct     -- Vrat
# Shastri      <--compound  -- Vrat
# Vrat         <--dobj      -- observed
# "            <--punct     -- Vrat
# .            <--punct     -- observed
# He           <--nsubj     -- motivated
# motivated    <--ROOT      -- motivated
# the          <--det       -- country
# country      <--dobj      -- motivated
# to           <--aux       -- maximize
# maximize     <--xcomp     -- motivated
# the          <--det       -- cultivation
# cultivation  <--dobj      -- maximize
# of           <--prep      -- cultivation
# food         <--compound  -- grains
# grains       <--pobj      -- of
# by           <--prep      -- maximize
# ploughing    <--pcomp     -- by
# the          <--det       -- lawn
# lawn         <--dobj      -- ploughing
# himself      <--appos     -- lawn
# ,            <--punct     -- maximize
# at           <--prep      -- maximize
# his          <--poss      -- residence
# official     <--amod      -- residence
# residence    <--pobj      -- at
# in           <--prep      -- residence
# New          <--compound  -- Delhi
# Delhi        <--pobj      -- in
# .            <--punct     -- motivated
# During       <--prep      -- gave
# the          <--det       -- war
# 22           <--nummod    -- day
# -            <--punct     -- day
# day          <--compound  -- war
# war          <--pobj      -- During
# with         <--prep      -- war
# Pakistan     <--pobj      -- with
# in           <--prep      -- war
# 1965         <--pobj      -- in
# ,            <--punct     -- gave
# On           <--prep      -- gave
# 19           <--nummod    -- October
# October      <--pobj      -- On
# 1965         <--nummod    -- October
# ,            <--punct     -- gave
# Shastri      <--nsubj     -- gave
# gave         <--ROOT      -- gave
# the          <--det       -- seminal
# seminal      <--amod      -- Kishan
# '            <--punct     -- Kishan
# Jai          <--compound  -- Kishan
# Jawan        <--compound  -- Kishan
# Jai          <--compound  -- Kishan
# Kishan       <--dobj      -- gave
# '            <--punct     -- Kishan
# (            <--punct     -- Hail
# "            <--punct     -- Hail
# Hail         <--nmod      -- slogan
# the          <--det       -- soldier
# soldier      <--dobj      -- Hail
# ,            <--punct     -- soldier
# Hail         <--conj      -- Hail
# the          <--det       -- farmer
# farmer       <--dobj      -- Hail
# "            <--punct     -- Hail
# )            <--punct     -- Hail
# slogan       <--dobj      -- gave
# at           <--prep      -- slogan
# Urwa         <--pobj      -- at
# in           <--prep      -- slogan
# Allahabad    <--pobj      -- in
# that         <--nsubj     -- became
# became       <--relcl     -- slogan
# a            <--det       -- slogan
# national     <--amod      -- slogan
# slogan       <--attr      -- became
# .            <--punct     -- gave
# Underlining  <--advcl     -- promoted
# the          <--det       -- need
# need         <--dobj      -- Underlining
# to           <--aux       -- boost
# boost        <--acl       -- need
# India        <--poss      -- production
# 's           <--case      -- India
# food         <--compound  -- production
# production   <--dobj      -- boost
# ,            <--punct     -- promoted
# Shastri      <--nsubj     -- promoted
# also         <--advmod    -- promoted
# promoted     <--ROOT      -- promoted
# the          <--det       -- Revolution
# Green        <--compound  -- Revolution
# Revolution   <--dobj      -- promoted
# in           <--prep      -- Revolution
# India        <--pobj      -- in
# in           <--prep      -- promoted
# 1965.[41][42][43 <--pobj      -- in
# ]            <--punct     -- promoted
# This         <--nsubj     -- led
# led          <--ROOT      -- led
# to           <--prep      -- led
# an           <--det       -- increase
# increase     <--pobj      -- to
# in           <--prep      -- increase
# food         <--compound  -- grain
# grain        <--compound  -- production
# production   <--pobj      -- in
# ,            <--punct     -- increase
# especially   <--advmod    -- in
# in           <--prep      -- increase
# Punjab       <--pobj      -- in
# ,            <--punct     -- Punjab
# Haryana      <--conj      -- Punjab
# ,            <--punct     -- Haryana
# and          <--cc        -- Haryana
# Uttar        <--compound  -- Pradesh
# Pradesh      <--conj      -- Haryana
# .            <--punct     -- led
# Major        <--amod      -- milestones
# milestones   <--nsubj     -- were
# in           <--prep      -- milestones
# this         <--det       -- undertaking
# undertaking  <--pobj      -- in
# were         <--ROOT      -- were
# the          <--det       -- development
# development  <--attr      -- were
# of           <--prep      -- development
# high         <--advmod    -- yielding
# -            <--punct     -- yielding
# yielding     <--amod      -- varieties
# varieties    <--pobj      -- of
# of           <--prep      -- varieties
# wheat,[44    <--pobj      -- of
# ]            <--punct     -- were
# and          <--cc        -- were
# rust         <--conj      -- were
# resistant    <--amod      -- strains
# strains      <--dobj      -- rust
# of           <--prep      -- strains
# wheat.[45][46 <--pobj      -- of
# ]            <--punct     -- wheat.[45][46
#
#
#
#           <--dep       -- ]
# Lal          <--compound  -- Bahadur
# Bahadur      <--compound  -- Shastri
# Shastri      <--appos     -- wheat.[45][46
# in           <--prep      -- rust
# 1964         <--pobj      -- in
#
#             <--dep       -- 1964
# Though       <--mark      -- was
# he           <--nsubj     -- was
# was          <--advcl     -- stated
# a            <--det       -- socialist
# socialist    <--attr      -- was
# ,            <--punct     -- stated
# Shastri      <--nsubj     -- stated
# stated       <--conj      -- were
# that         <--mark      -- have
# India        <--nsubj     -- have
# can          <--aux       -- have
# not          <--neg       -- have
# have         <--ccomp     -- stated
# a            <--det       -- type
# regimented   <--amod      -- type
# type         <--dobj      -- have
# of           <--prep      -- type
# economy      <--pobj      -- of
# .            <--punct     -- were
# His          <--poss      -- government
# government   <--nsubj     -- passed
# passed       <--ccomp     -- commemorated
# the          <--det       -- Act
# National     <--compound  -- Board
# Agricultural <--compound  -- Products
# Products     <--compound  -- Board
# Board        <--compound  -- Act
# Act          <--dobj      -- passed
# and          <--cc        -- passed
# was          <--conj      -- passed
# responsible  <--acomp     -- was
# for          <--prep      -- responsible
# setting      <--pcomp     -- for
# up           <--prt       -- setting
# the          <--det       -- Corporation
# Food         <--compound  -- Corporation
# Corporation  <--dobj      -- setting
# of           <--prep      -- Corporation
# India        <--pobj      -- of
# under        <--prep      -- setting
# the          <--det       -- Corporation
# Food         <--compound  -- Corporation
# Corporation  <--poss      -- 1964.[47
# 's           <--case      -- Corporation
# Act          <--compound  -- 1964.[47
# 1964.[47     <--pobj      -- under
# ]            <--punct     -- was
#
#
#            <--dep       -- ]
# Jai          <--compound  -- Jawan
# Jawan        <--compound  -- article
# Jai          <--compound  -- Kisan
# Kisan        <--nmod      -- article
#
#             <--dep       -- Kisan
# Main         <--amod      -- article
# article      <--attr      -- was
# :            <--punct     -- passed
# Jai          <--compound  -- Jawan
# Jawan        <--compound  -- Kisan
# Jai          <--compound  -- Kisan
# Kisan        <--dobj      -- passed
#
#             <--dep       -- Kisan
# For          <--prep      -- commemorated
# the          <--det       -- slogan
# outstanding  <--amod      -- slogan
# slogan       <--pobj      -- For
# given        <--acl       -- slogan
# by           <--agent     -- given
# him          <--pobj      -- by
# during       <--prep      -- given
# the          <--det       -- war
# Indo         <--compound  -- Pak
# -            <--punct     -- Pak
# Pak          <--compound  -- war
# war          <--pobj      -- during
# of           <--prep      -- war
# 1965         <--pobj      -- of
# ,            <--punct     -- commemorated
# the          <--det       -- Ministry
# Ministry     <--nsubj     -- commemorated
# of           <--prep      -- Ministry
# Information  <--pobj      -- of
# and          <--cc        -- Information
# Broadcasting <--conj      -- Information
# (            <--punct     -- Ministry
# India        <--appos     -- Ministry
# )            <--punct     -- Ministry
# commemorated <--ROOT      -- commemorated
# Shastri      <--nsubj     -- commemorated
# 47           <--nummod    -- years
# years        <--npadvmod  -- after
# after        <--prep      -- commemorated
# his          <--poss      -- death
# death        <--pobj      -- after
# on           <--prep      -- death
# his          <--poss      -- martyr
# 48th         <--amod      -- martyr
# martyr       <--poss      -- day:[48
# 's           <--case      -- martyr
# day:[48      <--pobj      -- on
# ]            <--punct     -- day:[48
#
#             <--dep       -- ]

# %% [markdown]
# #Sentence wise grammar parsing

# %%
for sent in doc.sents:
    print("Sentence:", sent.text)
    for token in sent:
        print(f"  {token.text:15} {token.pos_:10} {token.dep_:10} --> {token.head.text}")
    print()
# Out:
# Sentence:
# From Wikipedia, the free encyclopedia
# "Shastri" redirects here.
#
#                SPACE      dep        --> From
#   From            ADP        prep       --> redirects
#   Wikipedia       PROPN      pobj       --> From
#   ,               PUNCT      punct      --> Wikipedia
#   the             DET        det        --> encyclopedia
#   free            ADJ        amod       --> encyclopedia
#   encyclopedia    NOUN       compound   --> redirects
#
#                SPACE      dep        --> encyclopedia
#   "               PUNCT      punct      --> redirects
#   Shastri         ADJ        amod       --> redirects
#   "               PUNCT      punct      --> redirects
#   redirects       NOUN       ROOT       --> redirects
#   here            ADV        advmod     --> redirects
#   .               PUNCT      punct      --> redirects
#
# Sentence: For other uses, see Shastri (disambiguation).
#
#   For             ADP        prep       --> see
#   other           ADJ        amod       --> uses
#   uses            NOUN       pobj       --> For
#   ,               PUNCT      punct      --> see
#   see             VERB       ROOT       --> see
#   Shastri         PROPN      nsubj      --> see
#   (               PUNCT      punct      --> disambiguation
#   disambiguation  NOUN       appos      --> Shastri
#   )               PUNCT      punct      --> see
#   .               PUNCT      punct      --> see
#
#                SPACE      dep        --> .
#
# Sentence: Lal Bahadur Shastri
#
# Prime Minister of India
#
#   Lal             PROPN      compound   --> Bahadur
#   Bahadur         PROPN      ROOT       --> Bahadur
#   Shastri         PROPN      compound   --> Minister
#
#
#               SPACE      dep        --> Shastri
#   Prime           PROPN      compound   --> Minister
#   Minister        PROPN      appos      --> Bahadur
#   of              ADP        prep       --> Minister
#   India           PROPN      pobj       --> of
#
#                SPACE      dep        --> India
#
# Sentence: In office
# 9 June 1964 – 11 January 1966
# President	Sarvepalli Radhakrishnan
# Vice President	Zakir Husain
# Preceded by	Jawaharlal Nehru[a]
# Succeeded by	Indira Gandhi[b]
# Union Minister of External Affairs
#
#   In              ADP        ROOT       --> In
#   office          NOUN       pobj       --> In
#
#                SPACE      dep        --> office
#   9               NUM        nummod     --> June
#   June            PROPN      pobj       --> In
#   1964            NUM        nummod     --> June
#   –               PUNCT      punct      --> June
#   11              NUM        nummod     --> June
#   January         PROPN      nmod       --> President
#   1966            NUM        nummod     --> January
#
#                SPACE      dep        --> 1966
#   President       PROPN      compound   --> President
#   	               SPACE      dep        --> President
#   Sarvepalli      PROPN      compound   --> Radhakrishnan
#   Radhakrishnan   PROPN      compound   --> President
#
#                SPACE      dep        --> Radhakrishnan
#   Vice            PROPN      compound   --> President
#   President       PROPN      dep        --> In
#   	               SPACE      dep        --> President
#   Zakir           PROPN      compound   --> Husain
#   Husain          PROPN      compound   --> Preceded
#
#                SPACE      dep        --> Husain
#   Preceded        VERB       acl        --> President
#   by              ADP        prep       --> Preceded
#   	               SPACE      dep        --> by
#   Jawaharlal      PROPN      compound   --> Nehru[a
#   Nehru[a         PROPN      pobj       --> by
#   ]               PUNCT      punct      --> Preceded
#
#                SPACE      dep        --> ]
#   Succeeded       VERB       acl        --> President
#   by              ADP        agent      --> Succeeded
#   	               SPACE      dep        --> by
#   Indira          PROPN      compound   --> Minister
#   Gandhi[b        PROPN      nmod       --> Minister
#   ]               PUNCT      punct      --> Gandhi[b
#
#                SPACE      dep        --> ]
#   Union           PROPN      compound   --> Minister
#   Minister        PROPN      pobj       --> by
#   of              ADP        prep       --> Minister
#   External        PROPN      compound   --> Affairs
#   Affairs         PROPN      pobj       --> of
#
#                SPACE      dep        --> Affairs
#
# Sentence: In office
# 9 June 1964 – 18 July 1964
# Prime Minister	Himself
# Preceded by	Gulzarilal
#   In              ADP        ROOT       --> In
#   office          NOUN       pobj       --> In
#
#                SPACE      dep        --> office
#   9               NUM        nummod     --> June
#   June            PROPN      pobj       --> In
#   1964            NUM        nummod     --> June
#   –               PUNCT      punct      --> June
#   18              NUM        nummod     --> Minister
#   July            PROPN      nmod       --> Minister
#   1964            NUM        nummod     --> July
#
#                SPACE      dep        --> 1964
#   Prime           PROPN      compound   --> Minister
#   Minister        PROPN      appos      --> June
#   	               SPACE      dep        --> Minister
#   Himself         PROPN      appos      --> Minister
#
#                SPACE      dep        --> Himself
#   Preceded        VERB       acl        --> Minister
#   by              ADP        agent      --> Preceded
#   	               SPACE      dep        --> by
#   Gulzarilal      PROPN      pobj       --> by
#
# Sentence: Nanda
# Succeeded by	Sardar Swaran Singh
# Union Minister of Home Affairs
# In office
# 4 April 1961 – 29 August 1963
# Prime Minister	Jawaharlal Nehru
# Preceded by	Govind Ballabh Pant
# Succeeded by	Gulzarilal Nanda
# Union Minister of Railways
# In office
# 13 May 1952 – 7 December 1956
# Prime Minister	Jawaharlal Nehru
# Preceded by	N. Gopalaswami Ayyangar
# Succeeded by	Jagjivan Ram
# Personal details
# Born	Lal Bahadur Srivastava
# 2 October 1904
# Mughalsarai, United Provinces of Agra and Oudh, British India
# Died	11 January 1966 (aged 61)
# Tashkent, Uzbek SSR, Soviet Union
# Cause of death	Heart attack
# Party	Indian National Congress
# Spouse	Lalita Shastri ​(m.
#   Nanda           PROPN      dep        --> Died
#
#                SPACE      dep        --> Nanda
#   Succeeded       VERB       acl        --> Nanda
#   by              ADP        agent      --> Succeeded
#   	               SPACE      dep        --> by
#   Sardar          PROPN      compound   --> Minister
#   Swaran          PROPN      nmod       --> Singh
#   Singh           PROPN      nmod       --> Minister
#
#                SPACE      dep        --> Singh
#   Union           PROPN      compound   --> Minister
#   Minister        PROPN      pobj       --> by
#   of              ADP        prep       --> Minister
#   Home            PROPN      compound   --> Affairs
#   Affairs         PROPN      pobj       --> of
#
#                SPACE      dep        --> Affairs
#   In              ADP        prep       --> Nanda
#   office          NOUN       pobj       --> In
#
#                SPACE      dep        --> office
#   4               NUM        nummod     --> April
#   April           PROPN      npadvmod   --> Nanda
#   1961            NUM        nummod     --> April
#   –               PUNCT      punct      --> Nanda
#   29              NUM        nummod     --> August
#   August          PROPN      npadvmod   --> Nanda
#   1963            NUM        nummod     --> August
#
#                SPACE      dep        --> 1963
#   Prime           PROPN      compound   --> Minister
#   Minister        PROPN      compound   --> Nehru
#   	               SPACE      dep        --> Minister
#   Jawaharlal      PROPN      compound   --> Nehru
#   Nehru           PROPN      punct      --> August
#
#                SPACE      dep        --> Nehru
#   Preceded        VERB       acl        --> Nehru
#   by              ADP        prep       --> Preceded
#   	               SPACE      dep        --> by
#   Govind          PROPN      compound   --> Pant
#   Ballabh         PROPN      compound   --> Pant
#   Pant            PROPN      pobj       --> by
#
#                SPACE      dep        --> Pant
#   Succeeded       VERB       acl        --> Nehru
#   by              ADP        agent      --> Succeeded
#   	               SPACE      dep        --> by
#   Gulzarilal      PROPN      nmod       --> Minister
#   Nanda           PROPN      nmod       --> Minister
#
#                SPACE      dep        --> Nanda
#   Union           PROPN      compound   --> Minister
#   Minister        PROPN      pobj       --> by
#   of              ADP        prep       --> Minister
#   Railways        PROPN      pobj       --> of
#
#                SPACE      dep        --> Railways
#   In              ADP        prep       --> Nanda
#   office          NOUN       pobj       --> In
#
#                SPACE      dep        --> office
#   13              NUM        nummod     --> Nanda
#   May             PROPN      npadvmod   --> Nanda
#   1952            NUM        nummod     --> May
#   –               PUNCT      punct      --> Nanda
#   7               NUM        appos      --> Nanda
#   December        PROPN      npadvmod   --> Died
#   1956            NUM        nummod     --> December
#
#                SPACE      dep        --> 1956
#   Prime           PROPN      compound   --> Minister
#   Minister        PROPN      compound   --> Nehru
#   	               SPACE      dep        --> Minister
#   Jawaharlal      PROPN      compound   --> Nehru
#   Nehru           PROPN      punct      --> December
#
#                SPACE      dep        --> Nehru
#   Preceded        VERB       acl        --> Nehru
#   by              ADP        prep       --> Preceded
#   	               SPACE      dep        --> by
#   N.              PROPN      compound   --> Gopalaswami
#   Gopalaswami     PROPN      compound   --> Ayyangar
#   Ayyangar        PROPN      pobj       --> by
#
#                SPACE      dep        --> Ayyangar
#   Succeeded       VERB       acl        --> December
#   by              ADP        agent      --> Succeeded
#   	               SPACE      dep        --> by
#   Jagjivan        PROPN      compound   --> details
#   Ram             PROPN      compound   --> details
#
#                SPACE      dep        --> Ram
#   Personal        ADJ        amod       --> details
#   details         NOUN       pobj       --> by
#
#                SPACE      dep        --> details
#   Born            VERB       amod       --> Srivastava
#   	               SPACE      dep        --> Born
#   Lal             PROPN      compound   --> Srivastava
#   Bahadur         PROPN      compound   --> Srivastava
#   Srivastava      PROPN      appos      --> details
#
#                SPACE      dep        --> Srivastava
#   2               NUM        nummod     --> Mughalsarai
#   October         PROPN      nmod       --> Mughalsarai
#   1904            NUM        nummod     --> October
#
#                SPACE      dep        --> 1904
#   Mughalsarai     PROPN      appos      --> Srivastava
#   ,               PUNCT      punct      --> Mughalsarai
#   United          PROPN      compound   --> Provinces
#   Provinces       PROPN      appos      --> Mughalsarai
#   of              ADP        prep       --> Provinces
#   Agra            PROPN      pobj       --> of
#   and             CCONJ      cc         --> Agra
#   Oudh            PROPN      conj       --> Agra
#   ,               PUNCT      punct      --> Died
#   British         PROPN      compound   --> India
#   India           PROPN      nsubj      --> Died
#
#                SPACE      dep        --> India
#   Died            VERB       ROOT       --> Died
#   	               SPACE      dep        --> Died
#   11              NUM        dobj       --> Died
#   January         PROPN      npadvmod   --> Died
#   1966            NUM        nummod     --> January
#   (               PUNCT      punct      --> aged
#   aged            VERB       advcl      --> Died
#   61              NUM        nummod     --> aged
#   )               PUNCT      punct      --> 61
#
#                SPACE      dep        --> )
#   Tashkent        PROPN      npadvmod   --> aged
#   ,               PUNCT      punct      --> Tashkent
#   Uzbek           PROPN      compound   --> SSR
#   SSR             PROPN      conj       --> Tashkent
#   ,               PUNCT      punct      --> Tashkent
#   Soviet          PROPN      compound   --> Cause
#   Union           PROPN      compound   --> Cause
#
#                SPACE      dep        --> Union
#   Cause           PROPN      appos      --> Tashkent
#   of              ADP        prep       --> Cause
#   death           NOUN       compound   --> Party
#   	               SPACE      dep        --> death
#   Heart           PROPN      compound   --> Party
#   attack          NOUN       compound   --> Party
#
#                SPACE      dep        --> attack
#   Party           PROPN      compound   --> Lalita
#   	               SPACE      dep        --> Party
#   Indian          PROPN      compound   --> Lalita
#   National        PROPN      compound   --> Lalita
#   Congress        PROPN      compound   --> Lalita
#
#                SPACE      dep        --> Congress
#   Spouse          PROPN      compound   --> Lalita
#   	               SPACE      dep        --> Spouse
#   Lalita          PROPN      pobj       --> of
#   Shastri         PROPN      compound   --> ​(m
#   ​(m             PROPN      appos      --> Tashkent
#   .               PUNCT      punct      --> Died
#
# Sentence: 1928)​
# Children	6; including Anil Shastri, Hari Krishna Shastri and Sunil Shastri
# Alma mater	Mahatma Gandhi Kashi Vidyapith, Varanasi
# Profession	Politician
# Nickname	Nanhe
#
# This article is part of
# a series about
# Lal Bahadur Shastri
# Prime Minister of India
# (1964–1966)
#
#   1928)​          PROPN      compound   --> Children
#
#                SPACE      dep        --> 1928)​
#   Children        NOUN       nsubj      --> is
#   	               SPACE      dep        --> Children
#   6               NUM        nummod     --> Children
#   ;               PUNCT      punct      --> Children
#   including       VERB       prep       --> Children
#   Anil            PROPN      compound   --> Shastri
#   Shastri         PROPN      pobj       --> including
#   ,               PUNCT      punct      --> Shastri
#   Hari            PROPN      compound   --> Krishna
#   Krishna         PROPN      compound   --> Shastri
#   Shastri         PROPN      conj       --> Shastri
#   and             CCONJ      cc         --> Shastri
#   Sunil           PROPN      compound   --> Shastri
#   Shastri         PROPN      compound   --> Vidyapith
#
#                SPACE      dep        --> Shastri
#   Alma            PROPN      compound   --> mater
#   mater           NOUN       compound   --> Vidyapith
#   	               SPACE      dep        --> mater
#   Mahatma         PROPN      compound   --> Vidyapith
#   Gandhi          PROPN      compound   --> Vidyapith
#   Kashi           PROPN      compound   --> Vidyapith
#   Vidyapith       PROPN      nmod       --> article
#   ,               PUNCT      punct      --> Vidyapith
#   Varanasi        PROPN      compound   --> Nickname
#
#                SPACE      dep        --> Varanasi
#   Profession      PROPN      compound   --> Politician
#   	               SPACE      dep        --> Profession
#   Politician      PROPN      compound   --> Nickname
#
#                SPACE      dep        --> Politician
#   Nickname        PROPN      compound   --> Nanhe
#   	               SPACE      dep        --> Nickname
#   Nanhe           PROPN      appos      --> Vidyapith
#
#
#              SPACE      dep        --> Nanhe
#   This            DET        det        --> article
#   article         NOUN       conj       --> Shastri
#   is              AUX        ROOT       --> is
#   part            NOUN       attr       --> is
#   of              ADP        prep       --> part
#
#                SPACE      dep        --> of
#   a               DET        det        --> series
#   series          NOUN       pobj       --> of
#   about           ADP        prep       --> series
#
#                SPACE      dep        --> about
#   Lal             PROPN      compound   --> Bahadur
#   Bahadur         PROPN      pobj       --> about
#   Shastri         PROPN      compound   --> Minister
#
#                SPACE      dep        --> Shastri
#   Prime           PROPN      compound   --> Minister
#   Minister        PROPN      appos      --> Bahadur
#   of              ADP        prep       --> Minister
#   India           PROPN      pobj       --> of
#
#                SPACE      dep        --> India
#   (               PUNCT      punct      --> 1964–1966
#   1964–1966       NUM        appos      --> Minister
#   )               PUNCT      punct      --> 1964–1966
#
#                SPACE      dep        --> )
#
# Sentence: Early life and educationGandhi's discipleJai Jawan Jai KisanDeath and state funeralEponyms
# Premiership
#
# Union Council of Ministers ShastriLok
#   Early           ADJ        amod       --> life
#   life            NOUN       nsubj      --> educationGandhi
#   and             CCONJ      cc         --> life
#   educationGandhi VERB       ROOT       --> educationGandhi
#   's              PART       case       --> educationGandhi
#   discipleJai     NOUN       nsubj      --> educationGandhi
#   Jawan           PROPN      compound   --> KisanDeath
#   Jai             PROPN      compound   --> KisanDeath
#   KisanDeath      PROPN      attr       --> educationGandhi
#   and             CCONJ      cc         --> KisanDeath
#   state           NOUN       compound   --> funeralEponyms
#   funeralEponyms  NOUN       nmod       --> Council
#
#                SPACE      dep        --> funeralEponyms
#   Premiership     PROPN      compound   --> Council
#
#
#               SPACE      dep        --> Premiership
#   Union           PROPN      compound   --> Council
#   Council         PROPN      conj       --> KisanDeath
#   of              ADP        prep       --> Council
#   Ministers       PROPN      compound   --> ShastriLok
#   ShastriLok      PROPN      pobj       --> of
#
# Sentence: Sabha ThirdDomestic policiesEconomic policiesForeign policies
# Constitutional amendments
#
# 18th19th20th
# Events
#
# White RevolutionSirima–Shastri PactIndo-Pakistani War of 1965 Tashkent Declaration
# Lalita ShastriJai Jawaan Jai KisaanThe Tashkent Files
# Gallery:
#   Sabha           PROPN      nmod       --> ThirdDomestic
#   ThirdDomestic   PROPN      nmod       --> policies
#   policiesEconomic ADJ        amod       --> policiesForeign
#   policiesForeign VERB       amod       --> policies
#   policies        NOUN       ROOT       --> policies
#
#                SPACE      dep        --> policies
#   Constitutional  ADJ        amod       --> amendments
#   amendments      NOUN       appos      --> policies
#
#
#               SPACE      dep        --> amendments
#   18th19th20th    ADP        punct      --> amendments
#
#                SPACE      dep        --> 18th19th20th
#   Events          NOUN       pobj       --> 18th19th20th
#
#
#               SPACE      dep        --> Events
#   White           PROPN      compound   --> RevolutionSirima
#   RevolutionSirima PROPN      appos      --> amendments
#   –               PUNCT      punct      --> RevolutionSirima
#   Shastri         PROPN      compound   --> War
#   PactIndo        PROPN      compound   --> Pakistani
#   -               PUNCT      punct      --> Pakistani
#   Pakistani       PROPN      compound   --> War
#   War             PROPN      appos      --> RevolutionSirima
#   of              ADP        prep       --> War
#   1965            NUM        nummod     --> Gallery
#   Tashkent        PROPN      compound   --> Declaration
#   Declaration     PROPN      compound   --> Lalita
#
#                SPACE      dep        --> Declaration
#   Lalita          PROPN      compound   --> Jawaan
#   ShastriJai      PROPN      compound   --> Jawaan
#   Jawaan          PROPN      compound   --> Gallery
#   Jai             PROPN      compound   --> Gallery
#   KisaanThe       PROPN      compound   --> Gallery
#   Tashkent        PROPN      compound   --> Gallery
#   Files           PROPN      compound   --> Gallery
#
#                SPACE      dep        --> Files
#   Gallery         PROPN      pobj       --> of
#   :               PUNCT      punct      --> policies
#
# Sentence: Picture, Sound, Video
# vte
# Lal Bahadur Shastri[c] (2 October 1904 – 11 January 1966) was an Indian politician and statesman who served as the prime minister of India from 1964 to 1966.
#   Picture         PROPN      nsubj      --> was
#   ,               PUNCT      punct      --> Picture
#   Sound           PROPN      conj       --> Picture
#   ,               PUNCT      punct      --> Sound
#   Video           PROPN      compound   --> vte
#
#                SPACE      dep        --> Video
#   vte             PROPN      conj       --> Sound
#
#                SPACE      dep        --> vte
#   Lal             PROPN      compound   --> Bahadur
#   Bahadur         PROPN      compound   --> Shastri[c
#   Shastri[c       PROPN      appos      --> Picture
#   ]               X          punct      --> Picture
#   (               PUNCT      punct      --> Picture
#   2               NUM        appos      --> Picture
#   October         PROPN      appos      --> Picture
#   1904            NUM        nummod     --> October
#   –               PUNCT      punct      --> Picture
#   11              NUM        appos      --> Picture
#   January         PROPN      npadvmod   --> Picture
#   1966            NUM        nummod     --> January
#   )               PUNCT      punct      --> Picture
#   was             AUX        ROOT       --> was
#   an              DET        det        --> politician
#   Indian          ADJ        amod       --> politician
#   politician      NOUN       attr       --> was
#   and             CCONJ      cc         --> politician
#   statesman       NOUN       conj       --> politician
#   who             PRON       nsubj      --> served
#   served          VERB       relcl      --> politician
#   as              ADP        prep       --> served
#   the             DET        det        --> minister
#   prime           ADJ        amod       --> minister
#   minister        NOUN       pobj       --> as
#   of              ADP        prep       --> minister
#   India           PROPN      pobj       --> of
#   from            ADP        prep       --> served
#   1964            NUM        pobj       --> from
#   to              ADP        prep       --> from
#   1966            NUM        pobj       --> to
#   .               PUNCT      punct      --> was
#
# Sentence: He previously served as home minister from 1961 to 1963.
#
#
#   He              PRON       nsubj      --> served
#   previously      ADV        advmod     --> served
#   served          VERB       ROOT       --> served
#   as              ADP        prep       --> served
#   home            NOUN       compound   --> minister
#   minister        NOUN       pobj       --> as
#   from            ADP        prep       --> served
#   1961            NUM        pobj       --> from
#   to              ADP        prep       --> from
#   1963            NUM        pobj       --> to
#   .               PUNCT      punct      --> served
#
#
#               SPACE      dep        --> .
#
# Sentence: Shastri was born to Sharad Prasad Srivastava and Ramdulari Devi in Mughalsarai on 2 October 1904.
#   Shastri         PROPN      nsubjpass  --> born
#   was             AUX        auxpass    --> born
#   born            VERB       ROOT       --> born
#   to              ADP        prep       --> born
#   Sharad          PROPN      compound   --> Srivastava
#   Prasad          PROPN      compound   --> Srivastava
#   Srivastava      PROPN      pobj       --> to
#   and             CCONJ      cc         --> Srivastava
#   Ramdulari       PROPN      compound   --> Devi
#   Devi            PROPN      conj       --> Srivastava
#   in              ADP        prep       --> Srivastava
#   Mughalsarai     PROPN      pobj       --> in
#   on              ADP        prep       --> born
#   2               NUM        nummod     --> October
#   October         PROPN      pobj       --> on
#   1904            NUM        nummod     --> October
#   .               PUNCT      punct      --> born
#
# Sentence: He studied in East Central Railway Inter college and the Harish Chandra High School, which he left to join the non-cooperation movement.
#   He              PRON       nsubj      --> studied
#   studied         VERB       ROOT       --> studied
#   in              ADP        prep       --> studied
#   East            PROPN      compound   --> Central
#   Central         PROPN      compound   --> college
#   Railway         PROPN      compound   --> college
#   Inter           PROPN      compound   --> college
#   college         NOUN       pobj       --> in
#   and             CCONJ      cc         --> college
#   the             DET        det        --> School
#   Harish          PROPN      compound   --> School
#   Chandra         PROPN      compound   --> School
#   High            PROPN      compound   --> School
#   School          PROPN      conj       --> college
#   ,               PUNCT      punct      --> School
#   which           PRON       dobj       --> left
#   he              PRON       nsubj      --> left
#   left            VERB       relcl      --> School
#   to              PART       aux        --> join
#   join            VERB       xcomp      --> left
#   the             DET        det        --> movement
#   non             ADJ        amod       --> movement
#   -               ADJ        amod       --> movement
#   cooperation     ADJ        amod       --> movement
#   movement        NOUN       dobj       --> join
#   .               PUNCT      punct      --> studied
#
# Sentence: He worked for the betterment of the Harijans at Muzaffarpur and dropped his caste-derived surname of "Srivastava".
#   He              PRON       nsubj      --> worked
#   worked          VERB       ROOT       --> worked
#   for             ADP        prep       --> worked
#   the             DET        det        --> betterment
#   betterment      NOUN       pobj       --> for
#   of              ADP        prep       --> betterment
#   the             DET        det        --> Harijans
#   Harijans        PROPN      pobj       --> of
#   at              ADP        prep       --> worked
#   Muzaffarpur     PROPN      pobj       --> at
#   and             CCONJ      cc         --> worked
#   dropped         VERB       conj       --> worked
#   his             PRON       poss       --> surname
#   caste           NOUN       npadvmod   --> derived
#   -               PUNCT      punct      --> derived
#   derived         VERB       amod       --> surname
#   surname         NOUN       dobj       --> dropped
#   of              ADP        prep       --> surname
#   "               PUNCT      punct      --> Srivastava
#   Srivastava      PROPN      pobj       --> of
#   "               PUNCT      punct      --> Srivastava
#   .               PUNCT      punct      --> worked
#
# Sentence: Influenced by Mahatma Gandhi, he joined the Indian Independence movement in the 1920s.
#   Influenced      VERB       advcl      --> joined
#   by              ADP        agent      --> Influenced
#   Mahatma         PROPN      compound   --> Gandhi
#   Gandhi          PROPN      pobj       --> by
#   ,               PUNCT      punct      --> joined
#   he              PRON       nsubj      --> joined
#   joined          VERB       ROOT       --> joined
#   the             DET        det        --> movement
#   Indian          ADJ        amod       --> Independence
#   Independence    PROPN      compound   --> movement
#   movement        NOUN       dobj       --> joined
#   in              ADP        prep       --> joined
#   the             DET        det        --> 1920s
#   1920s           NUM        pobj       --> in
#   .               PUNCT      punct      --> joined
#
# Sentence: He served as the president of Servants of the People Society, founded by Lala Lajpat Rai and held prominent positions in the Indian National Congress (INC).
#   He              PRON       nsubj      --> served
#   served          VERB       ROOT       --> served
#   as              ADP        prep       --> served
#   the             DET        det        --> president
#   president       NOUN       pobj       --> as
#   of              ADP        prep       --> president
#   Servants        PROPN      pobj       --> of
#   of              ADP        prep       --> Servants
#   the             DET        det        --> Society
#   People          PROPN      compound   --> Society
#   Society         PROPN      pobj       --> of
#   ,               PUNCT      punct      --> served
#   founded         VERB       advcl      --> served
#   by              ADP        agent      --> founded
#   Lala            PROPN      compound   --> Lajpat
#   Lajpat          PROPN      compound   --> Rai
#   Rai             PROPN      pobj       --> by
#   and             CCONJ      cc         --> founded
#   held            VERB       conj       --> founded
#   prominent       ADJ        amod       --> positions
#   positions       NOUN       dobj       --> held
#   in              ADP        prep       --> positions
#   the             DET        det        --> Congress
#   Indian          PROPN      compound   --> Congress
#   National        PROPN      compound   --> Congress
#   Congress        PROPN      pobj       --> in
#   (               PUNCT      punct      --> Congress
#   INC             PROPN      appos      --> Congress
#   )               PUNCT      punct      --> Congress
#   .               PUNCT      punct      --> served
#
# Sentence: Following Indian independence in 1947, Shastri led several union ministries under prime minister Jawaharlal Nehru.
#
#
#   Following       VERB       prep       --> led
#   Indian          ADJ        amod       --> independence
#   independence    NOUN       pobj       --> Following
#   in              ADP        prep       --> independence
#   1947            NUM        pobj       --> in
#   ,               PUNCT      punct      --> led
#   Shastri         PROPN      nsubj      --> led
#   led             VERB       ROOT       --> led
#   several         ADJ        amod       --> ministries
#   union           NOUN       compound   --> ministries
#   ministries      NOUN       dobj       --> led
#   under           ADP        prep       --> led
#   prime           ADJ        compound   --> minister
#   minister        NOUN       compound   --> Nehru
#   Jawaharlal      PROPN      compound   --> Nehru
#   Nehru           PROPN      pobj       --> under
#   .               PUNCT      punct      --> led
#
#
#               SPACE      dep        --> .
#
# Sentence: As prime minister, Shastri promoted the White revolution (India), a national campaign to increase the production and supply of milk, by supporting the Amul milk co-operative and creating the National Dairy Development Board.
#   As              ADP        prep       --> promoted
#   prime           ADJ        amod       --> minister
#   minister        NOUN       pobj       --> As
#   ,               PUNCT      punct      --> promoted
#   Shastri         PROPN      nsubj      --> promoted
#   promoted        VERB       ROOT       --> promoted
#   the             DET        det        --> revolution
#   White           PROPN      compound   --> revolution
#   revolution      PROPN      dobj       --> promoted
#   (               PUNCT      punct      --> revolution
#   India           PROPN      appos      --> revolution
#   )               PUNCT      punct      --> revolution
#   ,               PUNCT      punct      --> revolution
#   a               DET        det        --> campaign
#   national        ADJ        amod       --> campaign
#   campaign        NOUN       appos      --> revolution
#   to              PART       aux        --> increase
#   increase        VERB       acl        --> campaign
#   the             DET        det        --> production
#   production      NOUN       dobj       --> increase
#   and             CCONJ      cc         --> production
#   supply          NOUN       conj       --> production
#   of              ADP        prep       --> production
#   milk            NOUN       pobj       --> of
#   ,               PUNCT      punct      --> revolution
#   by              ADP        prep       --> promoted
#   supporting      VERB       pcomp      --> by
#   the             DET        det        --> milk
#   Amul            PROPN      compound   --> milk
#   milk            NOUN       dobj       --> supporting
#   co              ADJ        oprd       --> supporting
#   -               ADJ        dobj       --> supporting
#   operative       ADJ        acomp      --> supporting
#   and             CCONJ      cc         --> supporting
#   creating        VERB       conj       --> supporting
#   the             DET        det        --> Board
#   National        PROPN      compound   --> Board
#   Dairy           PROPN      compound   --> Board
#   Development     PROPN      compound   --> Board
#   Board           PROPN      dobj       --> creating
#   .               PUNCT      punct      --> promoted
#
# Sentence: Underlining the need to boost India's food production, Shastri also promoted the Green Revolution in India in 1965.
#   Underlining     VERB       advcl      --> promoted
#   the             DET        det        --> need
#   need            NOUN       dobj       --> Underlining
#   to              PART       aux        --> boost
#   boost           VERB       acl        --> need
#   India           PROPN      poss       --> production
#   's              PART       case       --> India
#   food            NOUN       compound   --> production
#   production      NOUN       dobj       --> boost
#   ,               PUNCT      punct      --> promoted
#   Shastri         PROPN      nsubj      --> promoted
#   also            ADV        advmod     --> promoted
#   promoted        VERB       ROOT       --> promoted
#   the             DET        det        --> Revolution
#   Green           PROPN      compound   --> Revolution
#   Revolution      PROPN      dobj       --> promoted
#   in              ADP        prep       --> Revolution
#   India           PROPN      pobj       --> in
#   in              ADP        prep       --> promoted
#   1965            NUM        pobj       --> in
#   .               PUNCT      punct      --> promoted
#
# Sentence: This led to an increase in food grain production, especially in the states of Punjab, Haryana and Uttar Pradesh.
#   This            PRON       nsubj      --> led
#   led             VERB       ROOT       --> led
#   to              ADP        prep       --> led
#   an              DET        det        --> increase
#   increase        NOUN       pobj       --> to
#   in              ADP        prep       --> increase
#   food            NOUN       compound   --> grain
#   grain           NOUN       compound   --> production
#   production      NOUN       pobj       --> in
#   ,               PUNCT      punct      --> led
#   especially      ADV        advmod     --> in
#   in              ADP        prep       --> led
#   the             DET        det        --> states
#   states          NOUN       pobj       --> in
#   of              ADP        prep       --> states
#   Punjab          PROPN      pobj       --> of
#   ,               PUNCT      punct      --> Punjab
#   Haryana         PROPN      conj       --> Punjab
#   and             CCONJ      cc         --> Haryana
#   Uttar           PROPN      compound   --> Pradesh
#   Pradesh         PROPN      conj       --> Haryana
#   .               PUNCT      punct      --> led
#
# Sentence: He led the country during the Indo-Pakistani war of 1965.
#   He              PRON       nsubj      --> led
#   led             VERB       ROOT       --> led
#   the             DET        det        --> country
#   country         NOUN       dobj       --> led
#   during          ADP        prep       --> led
#   the             DET        det        --> war
#   Indo            PROPN      compound   --> Pakistani
#   -               PUNCT      punct      --> Pakistani
#   Pakistani       ADJ        amod       --> war
#   war             NOUN       pobj       --> during
#   of              ADP        prep       --> war
#   1965            NUM        pobj       --> of
#   .               PUNCT      punct      --> led
#
# Sentence: His slogan "Jai Jawan, Jai Kisan" ("Hail to the soldier; Hail to the farmer") became very popular during the war.
#   His             PRON       poss       --> slogan
#   slogan          NOUN       nsubj      --> became
#   "               PUNCT      punct      --> slogan
#   Jai             PROPN      compound   --> Jawan
#   Jawan           PROPN      appos      --> slogan
#   ,               PUNCT      punct      --> Jawan
#   Jai             PROPN      compound   --> Kisan
#   Kisan           PROPN      appos      --> Jawan
#   "               PUNCT      punct      --> slogan
#   (               PUNCT      punct      --> Hail
#   "               PUNCT      punct      --> Hail
#   Hail            NOUN       nsubj      --> became
#   to              ADP        prep       --> Hail
#   the             DET        det        --> soldier
#   soldier         NOUN       pobj       --> to
#   ;               PUNCT      punct      --> Hail
#   Hail            NOUN       appos      --> Hail
#   to              ADP        prep       --> Hail
#   the             DET        det        --> farmer
#   farmer          NOUN       pobj       --> to
#   "               PUNCT      punct      --> Hail
#   )               PUNCT      punct      --> Hail
#   became          VERB       ROOT       --> became
#   very            ADV        advmod     --> popular
#   popular         ADJ        acomp      --> became
#   during          ADP        prep       --> became
#   the             DET        det        --> war
#   war             NOUN       pobj       --> during
#   .               PUNCT      punct      --> became
#
# Sentence: The war formally ended with the Tashkent Declaration on 10 January 1966; Shastri died the next day.
#
#
#   The             DET        det        --> war
#   war             NOUN       nsubj      --> ended
#   formally        ADV        advmod     --> ended
#   ended           VERB       ccomp      --> died
#   with            ADP        prep       --> ended
#   the             DET        det        --> Declaration
#   Tashkent        PROPN      compound   --> Declaration
#   Declaration     PROPN      pobj       --> with
#   on              ADP        prep       --> ended
#   10              NUM        nummod     --> January
#   January         PROPN      pobj       --> on
#   1966            NUM        nummod     --> January
#   ;               PUNCT      punct      --> died
#   Shastri         PROPN      nsubj      --> died
#   died            VERB       ROOT       --> died
#   the             DET        det        --> day
#   next            ADJ        amod       --> day
#   day             NOUN       npadvmod   --> died
#   .               PUNCT      punct      --> died
#
#
#               SPACE      dep        --> .
#
# Sentence: Early years (1904–1920)
# Shastri was born on 2 October 1904 at the home of his maternal grandparents.[1][2]
#   Early           ADJ        amod       --> years
#   years           NOUN       npadvmod   --> born
#   (               PUNCT      punct      --> years
#   1904–1920       NUM        appos      --> years
#   )               PUNCT      punct      --> years
#
#                SPACE      dep        --> )
#   Shastri         PROPN      nsubjpass  --> born
#   was             AUX        auxpass    --> born
#   born            VERB       ROOT       --> born
#   on              ADP        prep       --> born
#   2               NUM        nummod     --> October
#   October         PROPN      pobj       --> on
#   1904            NUM        nummod     --> October
#   at              ADP        prep       --> born
#   the             DET        det        --> home
#   home            NOUN       pobj       --> at
#   of              ADP        prep       --> home
#   his             PRON       poss       --> grandparents.[1][2
#   maternal        ADJ        amod       --> grandparents.[1][2
#   grandparents.[1][2 PROPN      pobj       --> of
#   ]               PUNCT      punct      --> born
#
# Sentence: Shastri's paternal ancestors were in the service of the zamindar of Ramnagar in Banaras, and Shastri lived there for the first year of his life.
#   Shastri         PROPN      poss       --> ancestors
#   's              PART       case       --> Shastri
#   paternal        ADJ        amod       --> ancestors
#   ancestors       NOUN       nsubj      --> were
#   were            AUX        ROOT       --> were
#   in              ADP        prep       --> were
#   the             DET        det        --> service
#   service         NOUN       pobj       --> in
#   of              ADP        prep       --> service
#   the             DET        det        --> zamindar
#   zamindar        NOUN       pobj       --> of
#   of              ADP        prep       --> zamindar
#   Ramnagar        PROPN      pobj       --> of
#   in              ADP        prep       --> Ramnagar
#   Banaras         PROPN      pobj       --> in
#   ,               PUNCT      punct      --> were
#   and             CCONJ      cc         --> were
#   Shastri         PROPN      nsubj      --> lived
#   lived           VERB       conj       --> were
#   there           ADV        advmod     --> lived
#   for             ADP        prep       --> lived
#   the             DET        det        --> year
#   first           ADJ        amod       --> year
#   year            NOUN       pobj       --> for
#   of              ADP        prep       --> year
#   his             PRON       poss       --> life
#   life            NOUN       pobj       --> of
#   .               PUNCT      punct      --> lived
#
# Sentence: Shastri's father, Sharad Prasad Srivastava, was a school teacher who later became a clerk in the revenue office at Prayagraj, while his mother, Ramdulari Devi, was the daughter of Munshi Hazari Lal, the headmaster and English teacher at a railway school in Mughalsarai.
#   Shastri         PROPN      poss       --> father
#   's              PART       case       --> Shastri
#   father          NOUN       nsubj      --> was
#   ,               PUNCT      punct      --> father
#   Sharad          PROPN      compound   --> Srivastava
#   Prasad          PROPN      compound   --> Srivastava
#   Srivastava      PROPN      appos      --> father
#   ,               PUNCT      punct      --> father
#   was             AUX        ROOT       --> was
#   a               DET        det        --> teacher
#   school          NOUN       compound   --> teacher
#   teacher         NOUN       attr       --> was
#   who             PRON       nsubj      --> became
#   later           ADV        advmod     --> became
#   became          VERB       relcl      --> teacher
#   a               DET        det        --> clerk
#   clerk           NOUN       attr       --> became
#   in              ADP        prep       --> clerk
#   the             DET        det        --> office
#   revenue         NOUN       compound   --> office
#   office          NOUN       pobj       --> in
#   at              ADP        prep       --> became
#   Prayagraj       PROPN      pobj       --> at
#   ,               PUNCT      punct      --> was
#   while           SCONJ      mark       --> was
#   his             PRON       poss       --> mother
#   mother          NOUN       nsubj      --> was
#   ,               PUNCT      punct      --> mother
#   Ramdulari       PROPN      compound   --> Devi
#   Devi            PROPN      appos      --> mother
#   ,               PUNCT      punct      --> mother
#   was             AUX        advcl      --> was
#   the             DET        det        --> daughter
#   daughter        NOUN       attr       --> was
#   of              ADP        prep       --> daughter
#   Munshi          PROPN      compound   --> Hazari
#   Hazari          PROPN      compound   --> Lal
#   Lal             PROPN      pobj       --> of
#   ,               PUNCT      punct      --> Lal
#   the             DET        det        --> headmaster
#   headmaster      NOUN       appos      --> Lal
#   and             CCONJ      cc         --> headmaster
#   English         ADJ        amod       --> teacher
#   teacher         NOUN       conj       --> headmaster
#   at              ADP        prep       --> headmaster
#   a               DET        det        --> school
#   railway         NOUN       compound   --> school
#   school          NOUN       pobj       --> at
#   in              ADP        prep       --> school
#   Mughalsarai     PROPN      pobj       --> in
#   .               PUNCT      punct      --> was
#
# Sentence: Shastri was the second child and eldest son of his parents; he had an elder sister, Kailashi Devi (b. 1900).[3][4]
#
# In April 1905, when Shastri was hardly 18 months old, his father, who had recently been promoted to the post of deputy tehsildar, died in an epidemic of bubonic plague.
#   Shastri         PROPN      nsubj      --> was
#   was             AUX        ccomp      --> had
#   the             DET        det        --> child
#   second          ADJ        amod       --> child
#   child           NOUN       attr       --> was
#   and             CCONJ      cc         --> child
#   eldest          ADJ        amod       --> son
#   son             NOUN       conj       --> child
#   of              ADP        prep       --> son
#   his             PRON       poss       --> parents
#   parents         NOUN       pobj       --> of
#   ;               PUNCT      punct      --> had
#   he              PRON       nsubj      --> had
#   had             VERB       ROOT       --> had
#   an              DET        det        --> sister
#   elder           ADJ        amod       --> sister
#   sister          NOUN       dobj       --> had
#   ,               PUNCT      punct      --> sister
#   Kailashi        PROPN      compound   --> Devi
#   Devi            PROPN      appos      --> sister
#   (               PUNCT      punct      --> Devi
#   b.              PROPN      compound   --> 1900).[3][4
#   1900).[3][4     PROPN      appos      --> Devi
#   ]               PUNCT      punct      --> Devi
#
#
#               SPACE      dep        --> ]
#   In              ADP        prep       --> died
#   April           PROPN      pobj       --> In
#   1905            NUM        nummod     --> April
#   ,               PUNCT      punct      --> April
#   when            SCONJ      advmod     --> was
#   Shastri         PROPN      nsubj      --> was
#   was             AUX        relcl      --> April
#   hardly          ADV        advmod     --> 18
#   18              NUM        nummod     --> months
#   months          NOUN       npadvmod   --> old
#   old             ADJ        acomp      --> was
#   ,               PUNCT      punct      --> died
#   his             PRON       poss       --> father
#   father          NOUN       nsubj      --> died
#   ,               PUNCT      punct      --> father
#   who             PRON       nsubjpass  --> promoted
#   had             AUX        aux        --> promoted
#   recently        ADV        advmod     --> promoted
#   been            AUX        auxpass    --> promoted
#   promoted        VERB       relcl      --> father
#   to              ADP        prep       --> promoted
#   the             DET        det        --> post
#   post            NOUN       pobj       --> to
#   of              ADP        prep       --> post
#   deputy          ADJ        compound   --> tehsildar
#   tehsildar       NOUN       pobj       --> of
#   ,               PUNCT      punct      --> father
#   died            VERB       conj       --> had
#   in              ADP        prep       --> died
#   an              DET        det        --> epidemic
#   epidemic        NOUN       pobj       --> in
#   of              ADP        prep       --> epidemic
#   bubonic         ADJ        compound   --> plague
#   plague          NOUN       pobj       --> of
#   .               PUNCT      punct      --> died
#
# Sentence: Ramdulari Devi, then only 23 years old and pregnant with her third child, took her two children and moved from Ramnagar to her father's house in Mughalsarai and settled there for good.
#   Ramdulari       PROPN      compound   --> Devi
#   Devi            PROPN      nsubj      --> took
#   ,               PUNCT      punct      --> Devi
#   then            ADV        advmod     --> old
#   only            ADV        advmod     --> 23
#   23              NUM        nummod     --> years
#   years           NOUN       npadvmod   --> old
#   old             ADJ        amod       --> Devi
#   and             CCONJ      cc         --> old
# ...
#   to              PART       aux        --> skip
#   skip            VERB       advcl      --> appeal
#   a               DET        det        --> meal
#   meal            NOUN       dobj       --> skip
#   a               DET        det        --> week
#   week            NOUN       npadvmod   --> skip
#   .               PUNCT      punct      --> went
#
# Sentence: The response to his appeal was overwhelming.
#   The             DET        det        --> response
#   response        NOUN       nsubj      --> was
#   to              ADP        prep       --> response
#   his             PRON       poss       --> appeal
#   appeal          NOUN       pobj       --> to
#   was             AUX        ROOT       --> was
#   overwhelming    ADJ        acomp      --> was
#   .               PUNCT      punct      --> was
#
# Sentence: Even restaurants and eateries downed the shutters on Monday evenings.
#   Even            ADV        advmod     --> restaurants
#   restaurants     NOUN       nsubj      --> downed
#   and             CCONJ      cc         --> restaurants
#   eateries        NOUN       conj       --> restaurants
#   downed          VERB       ROOT       --> downed
#   the             DET        det        --> shutters
#   shutters        NOUN       dobj       --> downed
#   on              ADP        prep       --> downed
#   Monday          PROPN      compound   --> evenings
#   evenings        NOUN       pobj       --> on
#   .               PUNCT      punct      --> downed
#
# Sentence: Many parts of the country observed the "Shastri Vrat".
#   Many            ADJ        amod       --> parts
#   parts           NOUN       nsubj      --> observed
#   of              ADP        prep       --> parts
#   the             DET        det        --> country
#   country         NOUN       pobj       --> of
#   observed        VERB       ROOT       --> observed
#   the             DET        det        --> Vrat
#   "               PUNCT      punct      --> Vrat
#   Shastri         PROPN      compound   --> Vrat
#   Vrat            PROPN      dobj       --> observed
#   "               PUNCT      punct      --> Vrat
#   .               PUNCT      punct      --> observed
#
# Sentence: He motivated the country to maximize the cultivation of food grains by ploughing the lawn himself, at his official residence in New Delhi.
#   He              PRON       nsubj      --> motivated
#   motivated       VERB       ROOT       --> motivated
#   the             DET        det        --> country
#   country         NOUN       dobj       --> motivated
#   to              PART       aux        --> maximize
#   maximize        VERB       xcomp      --> motivated
#   the             DET        det        --> cultivation
#   cultivation     NOUN       dobj       --> maximize
#   of              ADP        prep       --> cultivation
#   food            NOUN       compound   --> grains
#   grains          NOUN       pobj       --> of
#   by              ADP        prep       --> maximize
#   ploughing       VERB       pcomp      --> by
#   the             DET        det        --> lawn
#   lawn            NOUN       dobj       --> ploughing
#   himself         PRON       appos      --> lawn
#   ,               PUNCT      punct      --> maximize
#   at              ADP        prep       --> maximize
#   his             PRON       poss       --> residence
#   official        ADJ        amod       --> residence
#   residence       NOUN       pobj       --> at
#   in              ADP        prep       --> residence
#   New             PROPN      compound   --> Delhi
#   Delhi           PROPN      pobj       --> in
#   .               PUNCT      punct      --> motivated
#
# Sentence: During the 22-day war with Pakistan in 1965, On 19 October 1965, Shastri gave the seminal 'Jai Jawan Jai Kishan' ("Hail the soldier, Hail the farmer") slogan at Urwa in Allahabad that became a national slogan.
#   During          ADP        prep       --> gave
#   the             DET        det        --> war
#   22              NUM        nummod     --> day
#   -               PUNCT      punct      --> day
#   day             NOUN       compound   --> war
#   war             NOUN       pobj       --> During
#   with            ADP        prep       --> war
#   Pakistan        PROPN      pobj       --> with
#   in              ADP        prep       --> war
#   1965            NUM        pobj       --> in
#   ,               PUNCT      punct      --> gave
#   On              ADP        prep       --> gave
#   19              NUM        nummod     --> October
#   October         PROPN      pobj       --> On
#   1965            NUM        nummod     --> October
#   ,               PUNCT      punct      --> gave
#   Shastri         PROPN      nsubj      --> gave
#   gave            VERB       ROOT       --> gave
#   the             DET        det        --> seminal
#   seminal         ADJ        amod       --> Kishan
#   '               PUNCT      punct      --> Kishan
#   Jai             PROPN      compound   --> Kishan
#   Jawan           PROPN      compound   --> Kishan
#   Jai             PROPN      compound   --> Kishan
#   Kishan          PROPN      dobj       --> gave
#   '               PUNCT      punct      --> Kishan
#   (               PUNCT      punct      --> Hail
#   "               PUNCT      punct      --> Hail
#   Hail            PROPN      nmod       --> slogan
#   the             DET        det        --> soldier
#   soldier         NOUN       dobj       --> Hail
#   ,               PUNCT      punct      --> soldier
#   Hail            PROPN      conj       --> Hail
#   the             DET        det        --> farmer
#   farmer          NOUN       dobj       --> Hail
#   "               PUNCT      punct      --> Hail
#   )               PUNCT      punct      --> Hail
#   slogan          NOUN       dobj       --> gave
#   at              ADP        prep       --> slogan
#   Urwa            PROPN      pobj       --> at
#   in              ADP        prep       --> slogan
#   Allahabad       PROPN      pobj       --> in
#   that            PRON       nsubj      --> became
#   became          VERB       relcl      --> slogan
#   a               DET        det        --> slogan
#   national        ADJ        amod       --> slogan
#   slogan          NOUN       attr       --> became
#   .               PUNCT      punct      --> gave
#
# Sentence: Underlining the need to boost India's food production, Shastri also promoted the Green Revolution in India in 1965.[41][42][43]
#   Underlining     VERB       advcl      --> promoted
#   the             DET        det        --> need
#   need            NOUN       dobj       --> Underlining
#   to              PART       aux        --> boost
#   boost           VERB       acl        --> need
#   India           PROPN      poss       --> production
#   's              PART       case       --> India
#   food            NOUN       compound   --> production
#   production      NOUN       dobj       --> boost
#   ,               PUNCT      punct      --> promoted
#   Shastri         PROPN      nsubj      --> promoted
#   also            ADV        advmod     --> promoted
#   promoted        VERB       ROOT       --> promoted
#   the             DET        det        --> Revolution
#   Green           PROPN      compound   --> Revolution
#   Revolution      PROPN      dobj       --> promoted
#   in              ADP        prep       --> Revolution
#   India           PROPN      pobj       --> in
#   in              ADP        prep       --> promoted
#   1965.[41][42][43 NUM        pobj       --> in
#   ]               PUNCT      punct      --> promoted
#
# Sentence: This led to an increase in food grain production, especially in Punjab, Haryana, and Uttar Pradesh.
#   This            PRON       nsubj      --> led
#   led             VERB       ROOT       --> led
#   to              ADP        prep       --> led
#   an              DET        det        --> increase
#   increase        NOUN       pobj       --> to
#   in              ADP        prep       --> increase
#   food            NOUN       compound   --> grain
#   grain           NOUN       compound   --> production
#   production      NOUN       pobj       --> in
#   ,               PUNCT      punct      --> increase
#   especially      ADV        advmod     --> in
#   in              ADP        prep       --> increase
#   Punjab          PROPN      pobj       --> in
#   ,               PUNCT      punct      --> Punjab
#   Haryana         PROPN      conj       --> Punjab
#   ,               PUNCT      punct      --> Haryana
#   and             CCONJ      cc         --> Haryana
#   Uttar           PROPN      compound   --> Pradesh
#   Pradesh         PROPN      conj       --> Haryana
#   .               PUNCT      punct      --> led
#
# Sentence: Major milestones in this undertaking were the development of high-yielding varieties of wheat,[44] and rust resistant strains of wheat.[45][46]
#
#
# Lal Bahadur Shastri in 1964
# Though he was a socialist, Shastri stated that India cannot have a regimented type of economy.
#   Major           ADJ        amod       --> milestones
#   milestones      NOUN       nsubj      --> were
#   in              ADP        prep       --> milestones
#   this            DET        det        --> undertaking
#   undertaking     NOUN       pobj       --> in
#   were            AUX        ROOT       --> were
#   the             DET        det        --> development
#   development     NOUN       attr       --> were
#   of              ADP        prep       --> development
#   high            ADV        advmod     --> yielding
#   -               PUNCT      punct      --> yielding
#   yielding        VERB       amod       --> varieties
#   varieties       NOUN       pobj       --> of
#   of              ADP        prep       --> varieties
#   wheat,[44       NOUN       pobj       --> of
#   ]               PUNCT      punct      --> were
#   and             CCONJ      cc         --> were
#   rust            VERB       conj       --> were
#   resistant       ADJ        amod       --> strains
#   strains         NOUN       dobj       --> rust
#   of              ADP        prep       --> strains
#   wheat.[45][46   X          pobj       --> of
#   ]               PUNCT      punct      --> wheat.[45][46
#
#
#
#              SPACE      dep        --> ]
#   Lal             PROPN      compound   --> Bahadur
#   Bahadur         PROPN      compound   --> Shastri
#   Shastri         PROPN      appos      --> wheat.[45][46
#   in              ADP        prep       --> rust
#   1964            NUM        pobj       --> in
#
#                SPACE      dep        --> 1964
#   Though          SCONJ      mark       --> was
#   he              PRON       nsubj      --> was
#   was             AUX        advcl      --> stated
#   a               DET        det        --> socialist
#   socialist       NOUN       attr       --> was
#   ,               PUNCT      punct      --> stated
#   Shastri         PROPN      nsubj      --> stated
#   stated          VERB       conj       --> were
#   that            SCONJ      mark       --> have
#   India           PROPN      nsubj      --> have
#   can             AUX        aux        --> have
#   not             PART       neg        --> have
#   have            VERB       ccomp      --> stated
#   a               DET        det        --> type
#   regimented      ADJ        amod       --> type
#   type            NOUN       dobj       --> have
#   of              ADP        prep       --> type
#   economy         NOUN       pobj       --> of
#   .               PUNCT      punct      --> were
#
# Sentence: His government passed the National Agricultural Products Board Act and was responsible for setting up the Food Corporation of India under the Food Corporation's Act 1964.[47]
#
# Jai Jawan Jai Kisan
# Main article: Jai Jawan Jai Kisan
# For the outstanding slogan given by him during the Indo-Pak war of 1965, the Ministry of Information and Broadcasting (India) commemorated Shastri 47 years after his death on his 48th martyr's day:[48]
#
#   His             PRON       poss       --> government
#   government      NOUN       nsubj      --> passed
#   passed          VERB       ccomp      --> commemorated
#   the             DET        det        --> Act
#   National        PROPN      compound   --> Board
#   Agricultural    PROPN      compound   --> Products
#   Products        PROPN      compound   --> Board
#   Board           PROPN      compound   --> Act
#   Act             PROPN      dobj       --> passed
#   and             CCONJ      cc         --> passed
#   was             AUX        conj       --> passed
#   responsible     ADJ        acomp      --> was
#   for             ADP        prep       --> responsible
#   setting         VERB       pcomp      --> for
#   up              ADP        prt        --> setting
#   the             DET        det        --> Corporation
#   Food            PROPN      compound   --> Corporation
#   Corporation     PROPN      dobj       --> setting
#   of              ADP        prep       --> Corporation
#   India           PROPN      pobj       --> of
#   under           ADP        prep       --> setting
#   the             DET        det        --> Corporation
#   Food            PROPN      compound   --> Corporation
#   Corporation     PROPN      poss       --> 1964.[47
#   's              PART       case       --> Corporation
#   Act             PROPN      compound   --> 1964.[47
#   1964.[47        PROPN      pobj       --> under
#   ]               PUNCT      punct      --> was
#
#
#               SPACE      dep        --> ]
#   Jai             PROPN      compound   --> Jawan
#   Jawan           PROPN      compound   --> article
#   Jai             PROPN      compound   --> Kisan
#   Kisan           PROPN      nmod       --> article
#
#                SPACE      dep        --> Kisan
#   Main            ADJ        amod       --> article
#   article         NOUN       attr       --> was
#   :               PUNCT      punct      --> passed
#   Jai             PROPN      compound   --> Jawan
#   Jawan           PROPN      compound   --> Kisan
#   Jai             PROPN      compound   --> Kisan
#   Kisan           PROPN      dobj       --> passed
#
#                SPACE      dep        --> Kisan
#   For             ADP        prep       --> commemorated
#   the             DET        det        --> slogan
#   outstanding     ADJ        amod       --> slogan
#   slogan          NOUN       pobj       --> For
#   given           VERB       acl        --> slogan
#   by              ADP        agent      --> given
#   him             PRON       pobj       --> by
#   during          ADP        prep       --> given
#   the             DET        det        --> war
#   Indo            PROPN      compound   --> Pak
#   -               PUNCT      punct      --> Pak
#   Pak             PROPN      compound   --> war
#   war             NOUN       pobj       --> during
#   of              ADP        prep       --> war
#   1965            NUM        pobj       --> of
#   ,               PUNCT      punct      --> commemorated
#   the             DET        det        --> Ministry
#   Ministry        PROPN      nsubj      --> commemorated
#   of              ADP        prep       --> Ministry
#   Information     PROPN      pobj       --> of
#   and             CCONJ      cc         --> Information
#   Broadcasting    PROPN      conj       --> Information
#   (               PUNCT      punct      --> Ministry
#   India           PROPN      appos      --> Ministry
#   )               PUNCT      punct      --> Ministry
#   commemorated    VERB       ROOT       --> commemorated
#   Shastri         PROPN      nsubj      --> commemorated
#   47              NUM        nummod     --> years
#   years           NOUN       npadvmod   --> after
#   after           ADP        prep       --> commemorated
#   his             PRON       poss       --> death
#   death           NOUN       pobj       --> after
#   on              ADP        prep       --> death
#   his             PRON       poss       --> martyr
#   48th            ADJ        amod       --> martyr
#   martyr          NOUN       poss       --> day:[48
#   's              PART       case       --> martyr
#   day:[48         NOUN       pobj       --> on
#   ]               PUNCT      punct      --> day:[48
#
#                SPACE      dep        --> ]

# %% [markdown]
# #Visualization

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="14452debf3a4453a8742e65458aa8ceb-0" class="displacy" width="472550" height="1187.0" direction="ltr" style="max-width: none; height: 1187.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">From</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Wikipedia,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">encyclopedia</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">
# &quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">Shastri&quot;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">redirects</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">here.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">For</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">other</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">uses,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">see</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">Shastri (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">disambiguation).</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">Lal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">Bahadur</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Shastri</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">Prime</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Minister</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">India</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">In</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">office</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">9</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1097.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">June</tsp
